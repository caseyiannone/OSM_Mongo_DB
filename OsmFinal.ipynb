# %%
import pprint as pprint
import xml.etree.cElementTree as ET
import re
from collections import defaultdict
import time
import codecs
import json
from pymongo import MongoClient

# %% [markdown]
# ## Load File and Create Sample File

# %%
OSM_FILE = "chicago.osm"

# %%
#Create a sample file from the full chicago OSM data
SAMPLE_FILE = "chicago_sample.osm"

k = 150

def get_element(OSM_FILE, tags=('node', 'way', 'relation')):
    context = ET.iterparse(OSM_FILE, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()
            
            
with open (SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n ')

    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# # Explore OSM Data

# %% [markdown]
# #### Key value check

# %%
# Before you process the data and add it into MongoDB, you should
# check the "k" value for each "<tag>" and see if they can be valid keys in MongoDB,
# as well as see if there are any other potential problems.

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#determine if a tag matches one of the regular expression conditions above 
# and add a count to the dict for that condition

def key_type(element, keys):
    if element.tag == "tag":
       
        for tag in element.iter('tag'):
            tagk = tag.attrib['k']
            if lower.match(tagk):
                keys['lower'] += 1
            elif problemchars.match(tagk):
                keys['problemchars'] += 1
            elif lower_colon.match(tagk):
                keys['lower_colon'] += 1
            #if none of the searches as true add a count to 'other'
            else:
                keys['other'] += 1

    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
process_map(OSM_FILE)
# Out:
# {'lower': 1946125, 'lower_colon': 3088289, 'other': 1596539, 'problemchars': 0}

# %% [markdown]
# #### Tag Type Count | Map Parser

# %%
def get_element(filename):
   
    context = ET.iterparse(filename, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end':
            yield elem
            root.clear()


def count_tags (filename):
    tags_dict = defaultdict(int)
    for i, elem in enumerate(get_element(filename)):
        tags_dict[elem.tag] += 1
    return tags_dict

# %%
count_tags(OSM_FILE)
# Out:
# defaultdict(int,
#             {'bounds': 1,
#              'member': 85629,
#              'nd': 9927164,
#              'node': 8399408,
#              'osm': 1,
#              'relation': 4592,
#              'tag': 6630953,
#              'way': 1187563})

# %% [markdown]
# #### User IDs

# %%
def get_user(element):
    return

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.tag == 'node':
            for node in element.iter('node'):
                userid = node.attrib['uid']
                users.add(userid)

    return users

# %%
users = process_map(OSM_FILE)
pprint.pprint(users[0:6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0ec87fba073e> in <module>()
#       1 users = process_map(OSM_FILE)
# ----> 2 pprint.pprint(users[0:6])
#
# TypeError: 'set' object has no attribute '__getitem__'

# %% [markdown]
# #### Number of Unique Users

# %%
def get_user(element):
    return

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.tag == 'node':
            for node in element.iter('node'):
                userid = node.attrib['uid']
                users.add(userid)

    return users

# %%
len(process_map(OSM_FILE))
# Out:
# 2017

# %% [markdown]
# # Data Audit

# %%
"""
Your task in this exercise has two steps:
- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Circle", "South Avenue", "North", "South","East","West","Lane","Route"]

mapping = {"St": "Street", "St.": "Street", "street": "Street","st": "Street",
           "Dr": "Drive", "Dr.": "Drive","Ct":"Court", 
          "Blvd":"Boulevard","blvd":"Boulevard","Blvd.":"Boulevard", 
           "Ct.":"Court","HWY":"Highway",
           "Ln":"Lane","Ter":"Terrace","Ave.":"Avenue","Ave":"Avenue",
           "road":"Road","rd":"Road","Rd.":"Road","Rd": "Road","place":"Place","US":"U.S.",
           "Pl":"Place","Rte":"Route","IL":"Illinois","W":"West","Trl":"Trail",
           "avenue":"Avenue","Pkwy":"Parkway","Cir":"Circle",
            "N":"North","N.":"North","E":"East","S":"South","S":"South","S.":"South",
           "W.":"West","E.":"East","W":"West"
          }


def audit_street_type(street_types, street_name):
    """this function audit street name type"""
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    """this function if an attribute includes a street"""
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    """this function return all street name types"""
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def update_name(name, mapping):
    """this function update street name and make street name to be consistent"""
    name = name.replace(",", "")
    for word in name.split(" "):
        if word in mapping.keys():
            name = name.replace(word, mapping[word])

    return name


def output(osmfile):
    """This function print updated street name"""
    st_types = audit(osmfile)
    #assert len(st_types) == 3
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
    print "Pass"

# %%
output(OSM_FILE)
# Out:
# {'104': set(['North Sherman Avenue #104']),
#  '127': set(['Skokie Boulevard #127']),
#  '14': set(['Route 14', 'U.S. 14']),
#  '1425': set(['N Lake Shore Dr #1425']),
#  '176': set(['IL Route 176', 'Route 176']),
#  '1E': set(['West Waveland Avenue Apt 1E']),
#  '20': set(['US 20', 'West US Highway 20']),
#  '200': set(['Lake Street #200']),
#  '201': set(['Route 30, Suite 201']),
#  '2105': set(['North Michigan Avenue # 2105']),
#  '22': set(['E Route 22', 'Il 22']),
#  '231': set(['East US 231']),
#  '25': set(['Larkin Ave #25']),
#  '30': set(['US 30']),
#  '31': set(['Route 31']),
#  '321': set(['East Woodfield Road  #321']),
#  '34': set(['US 34', 'West Route 34']),
#  '38': set(['Route 38']),
#  '400': set(['South Michigan Avenue # 400']),
#  '47': set(['HWY 47', 'South Route 47']),
#  '500': set(['Thayer Court #500']),
#  '510': set(['W Madison St #510']),
#  '53': set(['Route 53']),
#  '59': set(['HWY 59',
#             'IL 59',
#             'Illinois 59',
#             'North Route 59',
#             'Route 59',
#             'Route IL 59',
#             'S HWY 59',
#             'S Route 59',
#             'S Rte 59',
#             'S. Route 59',
#             'South Route 59']),
#  '6': set(['US Highway 6']),
#  '60008': set(['60008']),
#  '60435': set(['1050 Essington Rd. Joliet, IL 60435']),
#  '64': set(['IL Route 64', 'Route 64']),
#  '8': set(['IL-59 #8']),
#  '83': set(['Route 83', 'South Route 83']),
#  'AVENUE': set(['SUNSET AVENUE']),
#  'Access': set(['North Breakwater Access']),
#  'Arrivals': set(["O'Hare Commercial Arrivals"]),
#  'Ave': set(['1st Ave',
#              '2752 W Montrose Ave',
#              'Belmont Ave',
#              'Central Ave',
#              'Cicero Ave',
#              'Dundee Ave',
#              'E Ogden Ave',
#              'E Park Ave',
#              'East 79th Ave',
#              'East Crystal Lake Ave',
#              'East Ogden Ave',
#              'Forest Ave',
#              'Harlem Ave',
#              'Jefferson Ave',
#              'Lake Ave',
#              'Larkin Ave',
#              'Lockwood Ave',
#              'Maple Ave',
#              'Milwaukee Ave',
#              'N Glenwood Ave',
#              'N Lincoln Ave',
#              'N Wheaton Ave',
#              'N. Glenwood Ave',
#              'North Milwaukee Ave',
#              'Ogden Ave',
#              'S Cicero Ave',
#              'S Harlem Ave',
#              'S Western Ave',
#              'S. Gary Ave',
#              'Sayre Ave',
#              'South Cicero Ave',
#              'South Gary Ave',
#              'South Kedzie Ave',
#              'South Lake Park Ave',
#              'Thatcher Ave',
#              'Torrence Ave',
#              'Touhy Ave',
#              'W 133rd Ave',
#              'W Dempster Ave',
#              'W Highland Ave',
#              'W Maple Ave',
#              'W North Ave',
#              'W Park Ave',
#              'W Prairie Ave',
#              'W Touhy Ave',
#              'West Euclid Ave',
#              'West Maple Ave',
#              'West North Ave',
#              'Wilmette Ave']),
#  'Ave.': set(['Brookfield Ave.',
#               'Burlington Ave.',
#               'Calumet Ave.',
#               'Milwaukee Ave.',
#               'Ogden Ave.',
#               'W Park Ave.',
#               'W. Euclid Ave.',
#               'Waiola Ave.']),
#  'Avebue': set(['North Milwaukee Avebue']),
#  'B': set(['South Avenue B']),
#  'Belmont': set(['Belmont']),
#  'Blvd': set(['Barclay Blvd',
#               'Franklin Blvd',
#               'Grand Blvd',
#               'Hansen Blvd',
#               'Naper Blvd',
#               'Oakwood Blvd',
#               'Patriot Blvd',
#               'Potawatomi Blvd',
#               'S Kenilworth Blvd',
#               'Sauk Blvd',
#               'Sibley Blvd',
#               'Timber Trails Blvd']),
#  'Blvd.': set(['Indianapolis Blvd.']),
#  'Bouevard': set(['West Garfield Bouevard']),
#  'Box': set(['PO Box']),
#  'Broadway': set(['Broadway',
#                   'N. Broadway',
#                   'North Broadway',
#                   'West Broadway']),
#  'C': set(['South Avenue C']),
#  'Center': set(['4905 Old Orchard Center',
#                 'Convenience Center',
#                 'Elk Grove Town Center',
#                 'Golf Mill Center',
#                 'Yorktown Center',
#                 'Yorktown Shopping Center']),
#  'Cir': set(['Aspen Cir', 'Glenbrook Cir', 'Wedgewood Cir']),
#  'Clark': set(['Clark']),
#  'Ct': set(['Alpine Ct',
#             'Andra Ct',
#             'Boulder Ct',
#             'Breckenridge Ct',
#             'Brittany Ct',
#             'Dillon Ct',
#             'Durango Ct',
#             'Glenbrook Ct',
#             'Hennessy Ct',
#             'Joan Ct',
#             'Kerry Ct',
#             'Kilkenny Ct',
#             'Leadville Ct',
#             'Loveland Ct',
#             'Pamela Ct',
#             'Park Ct',
#             'Pauline Ct',
#             'Powder Horn Ct',
#             'Telluride Ct',
#             'Timber Ct',
#             'Timber Trails Ct',
#             'Toll View Ct',
#             'Towne Ct',
#             'Vail Ct',
#             'Woodland Park Ct']),
#  'Ct.': set(['W. Peregrine Ct.']),
#  'D': set(['South Avenue D']),
#  'Dean': set(['Dean']),
#  'Dr': set(['Academic Dr',
#             'Alpine Dr',
#             'Arrowhead Dr',
#             'Augusta Dr',
#             'Authority Dr',
#             'Boulder Dr',
#             'Breckenridge Dr',
#             'Brentwood Dr',
#             'Briarwood Dr',
#             'Bushwood Dr',
#             'Charlestown Dr',
#             'Copper Mountain Dr',
#             'Fox Valley Center Dr',
#             'Greenbriar Dr',
#             'Gregory M Sears Dr',
#             'Industrial Dr',
#             'John M Boor Dr',
#             'Marketview Dr',
#             'Marquette Dr',
#             'Meadows Dr',
#             'N Bolingbrook Dr',
#             'North Upper Wacker Dr',
#             'Old Chicago Dr',
#             'Plaza Dr',
#             'Raymond Dr',
#             'Regent Dr',
#             'River Oaks Center Dr',
#             'Steamboat Dr',
#             'Summit Dr',
#             'Varsity Dr',
#             'Woodridge Dr',
#             'Wynstone Dr']),
#  'Dr.': set(['Auburn Dr.',
#              'Brentwood Dr.',
#              'Corporate Grove Dr.',
#              'W Lakeshore Dr.',
#              'W. Peregrine Dr.',
#              'Woodhead Dr.']),
#  'E': set(['Dana Square E', 'Danada Square E', 'South Avenue E']),
#  'F': set(['South Avenue F']),
#  'Fairfield': set(['S. Fairfield']),
#  'G': set(['South Avenue G']),
#  'Grove': set(['Grove']),
#  'H': set(['South Avenue H']),
#  'HWY': set(['W Lincoln HWY']),
#  'Harrison': set(['W. Harrison']),
#  'Highway': set(['Busse Highway',
#                  'Dixie Highway',
#                  'East Lincoln Highway',
#                  'East Northwest Highway',
#                  'Governors Highway',
#                  'Lincoln Highway',
#                  'North Northwest Highway',
#                  'Northwest Highway',
#                  'South Northwest Highway',
#                  'South Robert Kingery Highway',
#                  'W Lincoln Highway',
#                  'West Illinois Highway',
#                  'West Northwest Highway']),
#  'Hwy.': set(['W. Northwest Hwy.']),
#  'IL': set(['Yorktown Center 203 Yorktown Center Lombard, IL']),
#  'IL-53': set(['IL-53']),
#  'Innovation': set(['Innovation']),
#  'J': set(['South Avenue J']),
#  'Justamere': set(['Justamere']),
#  'K': set(['South Avenue K']),
#  'L': set(['South Avenue L']),
#  'LaSalle': set(['North LaSalle']),
#  'Larchmont': set(['Larchmont']),
#  'Ln': set(['Brighton Ln',
#             'Erica Ln',
#             'Evergreen Ln',
#             'Hendricks Ln',
#             'Leadville Ln',
#             'Running Deer Ln',
#             'Tipperary Ln',
#             'White Feather Ln']),
#  'M': set(['South Avenue M']),
#  'Market': set(['West Fulton Market']),
#  'Millsfell': set(['Millsfell']),
#  'N': set(['900 N', 'Parkway N', 'South Avenue N']),
#  'O': set(['South Avenue O']),
#  'Orrington': set(['Orrington']),
#  'PLACE': set(['West 78th PLACE']),
#  'Park': set(['East Groveland Park',
#               'East Madison Park',
#               'East Woodland Park',
#               'Ingleside Park',
#               'Milburn Park',
#               'South East View Park',
#               'West Midway Park']),
#  'Path': set(['Red Hawk Path', 'Shining Moon Path']),
#  'Pkwy': set(['E Countryside Pkwy',
#               'Veterans Pkwy',
#               'W Countryside Pkwy',
#               'W Veterans Pkwy',
#               'Wesmere Pkwy']),
#  'Pl': set(['Margaret Pl']),
#  'Plaza': set(['East Carver Plaza',
#                'Merchandise Mart Plaza',
#                'North Riverside Plaza',
#                'South Riverside Plaza',
#                'W Lincoln Plaza',
#                'W Merchandise Mart Plaza',
#                'West Wolf Point Plaza']),
#  'QQ': set(['Broadway, Suite QQ']),
#  'RD': set(['Randall RD']),
#  'Ravenswood': set(['North Ravenswood']),
#  'Rd': set(['Albright Rd',
#             'Beecher Rd',
#             'Big Timber Rd',
#             'Binder Rd',
#             'Bloomingdale Rd',
#             'Boughton Rd',
#             'Calument Sag Rd',
#             'Carpenter Rd',
#             'Clavey Rd',
#             'Crane Rd',
#             'Dara James Rd',
#             'Degroate Rd',
#             'E Higgins Rd',
#             'E Roosevelt Rd',
#             'E State Rd',
#             'East Higgins Rd',
#             'Freeman Rd',
#             'Galligan Rd',
#             'Game Farm Rd',
#             'Hobson Rd',
#             'Justamere Rd',
#             'Manheim Rd',
#             'Mannheim Rd',
#             'Mason Rd',
#             'McHenry Rd',
#             'Miller Rd',
#             'N Pfingsten Rd',
#             'N Rand Rd',
#             'N Randall Rd',
#             'N Rohlwing Rd',
#             'N Springinsguth Rd',
#             'N Weber Rd',
#             'N Wood Dale Rd',
#             'N. Waukegan Rd',
#             'Nelson Rd',
#             'Nesler Rd',
#             'Normantown Rd',
#             'North Randall Rd',
#             'Pingree Rd',
#             'Plainfield Rd',
#             'Pleasant Hill Rd',
#             'Plum Grove Rd',
#             'Powers Rd',
#             'Pyott Rd',
#             'Rand Rd',
#             'Randall Rd',
#             'Ridge Rd',
#             'S Barrington Rd',
#             'S Bell Rd',
#             'S Holland Rd',
#             'S LaGrange Rd',
#             'S Naperville Rd',
#             'S Weber Rd',
#             'Schmale Rd',
#             'Silver Glen Rd',
#             'South Eola Rd',
#             'Spinning Wheel Rd',
#             'Tower Hill Rd',
#             'Towncenter Rd',
#             'Tyrrell Rd',
#             'W Irving Park Rd',
#             'W Romeo Rd',
#             'W Schick Rd',
#             'Warrenville Rd',
#             'Waukegan Rd',
#             'Weber Rd',
#             'Willow Rd',
#             'Wise Rd']),
#  'Rd.': set(['E. Boughton Rd.',
#              'E. Rand Rd.',
#              'N. Rand Rd.',
#              'N. Wolf Rd.',
#              'S. Arlington Heights Rd.',
#              'St. Charles Rd.',
#              'W. State Rd.']),
#  'Row': set(['West Churchill Row']),
#  'Shabbona': set(['Shabbona']),
#  'St': set(['159th St',
#             '175th St',
#             'Capital St',
#             'Cross St',
#             'Deborah St',
#             'Dempster St',
#             'Division St',
#             'E 9th St',
#             'E Chicago St',
#             'Garden St',
#             'Harbor St',
#             'Jean St',
#             'John St',
#             'Kathleen St',
#             'Kildare St',
#             'Liberty St',
#             'Lillie St',
#             'Main St',
#             'N Broadway St',
#             'N Division St',
#             'N Ellsworth St',
#             'N Main St',
#             'N Railroad St',
#             'N State St',
#             'N. Carnation St',
#             'Nequa St',
#             'North Hough St',
#             'Ohio St',
#             'Park St',
#             'Pennsylvania St',
#             'Pierce St',
#             'Railroad St',
#             'Raymond St',
#             'Rose St',
#             'S 1st St',
#             'S 5th St',
#             'S 8th St',
#             'S Bridge St',
#             'S Fryer St',
#             'S Gilbert St',
#             'S Lincolnway St',
#             'S State St',
#             'Short St',
#             'State St',
#             'Suzanne St',
#             'Tipperary St',
#             'Towne St',
#             'W 111 St',
#             'W 183rd St',
#             'W 18th St',
#             'W Chicago St',
#             'W High St',
#             'W Lake St',
#             'W Lockport St',
#             'W Main St',
#             'W Maple St',
#             'W Monroe St',
#             'W Patterson St',
#             'W Somonauk St',
#             'W Washington St',
#             'W Wood St',
#             'Watch St',
#             'Webster St',
#             'Welch St',
#             'West Lake St']),
#  'St.': set(['E 75th St.',
#              'N. Main St.',
#              'North Bridge St.',
#              'Oakton St.',
#              'Valley View St.',
#              'W 129th St.',
#              'W Eames St.']),
#  'Ter': set(['Toll View Ter']),
#  'Terrace': set(['Colfax Terrace',
#                  'Harvard Terrace',
#                  'Hull Terrace',
#                  'North Alta Vista Terrace',
#                  'North Eastlake Terrace',
#                  'North Edgebrook Terrace',
#                  'North Geneva Terrace',
#                  'North Riversedge Terrace',
#                  'North Sandburg Terrace',
#                  'North Wesley Terrace',
#                  'Ridge Terrace',
#                  'South Park Terrace',
#                  'Suffield Terrace',
#                  'West Cahill Terrace',
#                  'West California Terrace',
#                  'West Castlewood Terrace',
#                  'West Gordon Terrace',
#                  'West Jonquil Terrace',
#                  'West Juneway Terrace',
#                  'West Junior Terrace',
#                  'West Margate Terrace',
#                  'West Westgate Terrace']),
#  'Trl': set(['Sleeping Bear Trl']),
#  'US-6': set(['US-6']),
#  'Vista': set(['North La Vista']),
#  'W': set(['River Oaks Cir W']),
#  'Walk': set(['North River Walk']),
#  'Way': set(['Audubon Way',
#              'Barberry Way',
#              'Galaxy Way',
#              'Lincoln Plaza Way',
#              'Peregrine Way',
#              'South Boulevard Way',
#              'Sports Way',
#              'Thornapple Way',
#              'UPS Way',
#              'Woodridge Way']),
#  'avenue': set(['Colombia avenue']),
#  'blvd': set(['Sauk blvd']),
#  'place': set(['223rd place']),
#  'rd': set(['East Algonquin rd', 'S. Rohlwing rd']),
#  'road': set(['E Algonquin road']),
#  'roosevelt': set(['roosevelt']),
#  'st': set(['E main st']),
#  'street': set(['Gostlin street'])}
# Albright Rd => Albright Road
# Freeman Rd => Freeman Road
# Tower Hill Rd => Tower Hill Road
# Big Timber Rd => Big Timber Road
# N Wood Dale Rd => North Wood Dale Road
# Silver Glen Rd => Silver Glen Road
# Pleasant Hill Rd => Pleasant Hill Road
# N Springinsguth Rd => North Springinsguth Road
# Miller Rd => Miller Road
# Rand Rd => Rand Road
# North Randall Rd => North Randall Road
# W Irving Park Rd => West Irving Park Road
# Plum Grove Rd => Plum Grove Road
# Schmale Rd => Schmale Road
# Game Farm Rd => Game Farm Road
# Ridge Rd => Ridge Road
# East Higgins Rd => East Higgins Road
# Justamere Rd => Justamere Road
# N Randall Rd => North Randall Road
# Crane Rd => Crane Road
# E State Rd => East State Road
# Nelson Rd => Nelson Road
# S Holland Rd => South Holland Road
# Beecher Rd => Beecher Road
# Weber Rd => Weber Road
# S LaGrange Rd => South LaGrange Road
# Hobson Rd => Hobson Road
# E Roosevelt Rd => East Roosevelt Road
# Pyott Rd => Pyott Road
# Willow Rd => Willow Road
# Randall Rd => Randall Road
# South Eola Rd => South Eola Road
# N Rand Rd => North Rand Road
# Wise Rd => Wise Road
# Bloomingdale Rd => Bloomingdale Road
# Normantown Rd => Normantown Road
# Spinning Wheel Rd => Spinning Wheel Road
# S Weber Rd => South Weber Road
# W Schick Rd => West Schick Road
# Carpenter Rd => Carpenter Road
# Calument Sag Rd => Calument Sag Road
# S Naperville Rd => South Naperville Road
# Boughton Rd => Boughton Road
# N. Waukegan Rd => North Waukegan Road
# Mason Rd => Mason Road
# Manheim Rd => Manheim Road
# Plainfield Rd => Plainfield Road
# McHenry Rd => McHenry Road
# W Romeo Rd => West Romeo Road
# Pingree Rd => Pingree Road
# E Higgins Rd => East Higgins Road
# S Barrington Rd => South Barrington Road
# Binder Rd => Binder Road
# N Pfingsten Rd => North Pfingsten Road
# Mannheim Rd => Mannheim Road
# Powers Rd => Powers Road
# Tyrrell Rd => Tyrrell Road
# Degroate Rd => Degroate Road
# Dara James Rd => Dara James Road
# Nesler Rd => Nesler Road
# Waukegan Rd => Waukegan Road
# Towncenter Rd => Towncenter Road
# N Rohlwing Rd => North Rohlwing Road
# Clavey Rd => Clavey Road
# S Bell Rd => South Bell Road
# N Weber Rd => North Weber Road
# Galligan Rd => Galligan Road
# Warrenville Rd => Warrenville Road
# Justamere => Justamere
# Innovation => Innovation
# Colombia avenue => Colombia Avenue
# Larkin Ave #25 => Larkin Avenue #25
# West US Highway 20 => West U.S. Highway 20
# US 20 => U.S. 20
# Il 22 => Il 22
# E Route 22 => East Route 22
# Randall RD => Randall RD
# W. Northwest Hwy. => West Northwest Hwy.
# South Michigan Avenue # 400 => South Michigan Avenue # 400
# IL-59 #8 => IL-59 #8
# Sleeping Bear Trl => Sleeping Bear Trail
# South Avenue H => South Avenue H
# South Avenue L => South Avenue L
# Wesmere Pkwy => Wesmere Parkway
# Veterans Pkwy => Veterans Parkway
# E Countryside Pkwy => East Countryside Parkway
# W Countryside Pkwy => West Countryside Parkway
# W Veterans Pkwy => West Veterans Parkway
# Wedgewood Cir => Wedgewood Circle
# Aspen Cir => Aspen Circle
# Glenbrook Cir => Glenbrook Circle
# Skokie Boulevard #127 => Skokie Boulevard #127
# North Breakwater Access => North Breakwater Access
# Route IL 59 => Route Illinois 59
# S Rte 59 => South Route 59
# Route 59 => Route 59
# Illinois 59 => Illinois 59
# IL 59 => Illinois 59
# S Route 59 => South Route 59
# North Route 59 => North Route 59
# South Route 59 => South Route 59
# S. Route 59 => South Route 59
# S HWY 59 => South Highway 59
# HWY 59 => Highway 59
# Belmont => Belmont
# Route 53 => Route 53
# Broadway => Broadway
# West Broadway => West Broadway
# North Broadway => North Broadway
# N. Broadway => North Broadway
# West Garfield Bouevard => West Garfield Bouevard
# Gostlin street => Gostlin Street
# W. Peregrine Dr. => West Peregrine Drive
# Auburn Dr. => Auburn Drive
# Woodhead Dr. => Woodhead Drive
# W Lakeshore Dr. => West Lakeshore Drive
# Corporate Grove Dr. => Corporate Grove Drive
# Brentwood Dr. => Brentwood Drive
# South Route 83 => South Route 83
# Route 83 => Route 83
# S. Arlington Heights Rd. => South Arlington Heights Road
# W. State Rd. => West State Road
# N. Rand Rd. => North Rand Road
# St. Charles Rd. => Street Charles Road
# E. Rand Rd. => East Rand Road
# E. Boughton Rd. => East Boughton Road
# N. Wolf Rd. => North Wolf Road
# SUNSET AVENUE => SUNSET AVENUE
# Margaret Pl => Margaret Place
# East Groveland Park => East Groveland Park
# East Woodland Park => East Woodland Park
# East Madison Park => East Madison Park
# Ingleside Park => Ingleside Park
# Milburn Park => Milburn Park
# South East View Park => South East View Park
# West Midway Park => West Midway Park
# East Algonquin rd => East Algonquin Road
# S. Rohlwing rd => South Rohlwing Road
# West Waveland Avenue Apt 1E => West Waveland Avenue Apt 1E
# North LaSalle => North LaSalle
# PO Box => PO Box
# South Avenue C => South Avenue C
# Calumet Ave. => Calumet Avenue
# W Park Ave. => West Park Avenue
# W. Euclid Ave. => West Euclid Avenue
# Brookfield Ave. => Brookfield Avenue
# Waiola Ave. => Waiola Avenue
# Burlington Ave. => Burlington Avenue
# Milwaukee Ave. => Milwaukee Avenue
# Ogden Ave. => Ogden Avenue
# South Avenue G => South Avenue G
# Grove => Grove
# South Avenue K => South Avenue K
# W Merchandise Mart Plaza => West Merchandise Mart Plaza
# West Wolf Point Plaza => West Wolf Point Plaza
# South Riverside Plaza => South Riverside Plaza
# East Carver Plaza => East Carver Plaza
# North Riverside Plaza => North Riverside Plaza
# Merchandise Mart Plaza => Merchandise Mart Plaza
# W Lincoln Plaza => West Lincoln Plaza
# O'Hare Commercial Arrivals => O'Hare Commercial Arrivals
# North Milwaukee Avebue => North Milwaukee Avebue
# West 78th PLACE => West 78th PLACE
# South Avenue O => South Avenue O
# River Oaks Cir W => River Oaks Circle West
# 60008 => 60008
# North Sherman Avenue #104 => North Sherman Avenue #104
# Indianapolis Blvd. => Indianapolis Boulevard
# Route 38 => Route 38
# Dean => Dean
# Clark => Clark
# Route 31 => Route 31
# US 30 => U.S. 30
# West Route 34 => West Route 34
# US 34 => U.S. 34
# 223rd place => 223rd Place
# North Michigan Avenue # 2105 => North Michigan Avenue # 2105
# W Madison St #510 => West Madison Street #510
# E Algonquin road => East Algonquin Road
# West Churchill Row => West Churchill Row
# US Highway 6 => U.S. Highway 6
# Oakton St. => Oakton Street
# Valley View St. => Valley View Street
# E 75th St. => East 75th Street
# W 129th St. => West 129th Street
# N. Main St. => North Main Street
# North Bridge St. => North Bridge Street
# W Eames St. => West Eames Street
# S. Fairfield => South Fairfield
# IL Route 64 => Illinois Route 64
# Route 64 => Route 64
# UPS Way => UPS Way
# Woodridge Way => Woodridge Way
# Sports Way => Sports Way
# Lincoln Plaza Way => Lincoln Plaza Way
# Audubon Way => Audubon Way
# South Boulevard Way => South Boulevard Way
# Barberry Way => Barberry Way
# Thornapple Way => Thornapple Way
# Galaxy Way => Galaxy Way
# Peregrine Way => Peregrine Way
# Route 176 => Route 176
# IL Route 176 => Illinois Route 176
# N Lake Shore Dr #1425 => North Lake Shore Drive #1425
# W Lincoln HWY => West Lincoln HWestY
# Thayer Court #500 => Thayer Court #500
# South Avenue B => South Avenue B
# Golf Mill Center => Golf Mill Center
# Yorktown Center => Yorktown Center
# Elk Grove Town Center => Elk Grove Town Center
# Convenience Center => Convenience Center
# 4905 Old Orchard Center => 4905 Old Orchard Center
# Yorktown Shopping Center => Yorktown Shopping Center
# South Avenue F => South Avenue F
# South Avenue J => South Avenue J
# S 8th St => South 8th Southt
# N State St => North Streetate Street
# W Wood St => West Westood Street
# W Washington St => West Westashington Street
# 159th St => 159th Street
# S Fryer St => South Fryer Southt
# S Lincolnway St => South Lincolnway Southt
# North Hough St => North Hough Street
# John St => John Street
# Ohio St => Ohio Street
# N. Carnation St => North Carnation Street
# E 9th St => East 9th Street
# 175th St => 175th Street
# Capital St => Capital Street
# Jean St => Jean Street
# Harbor St => Harbor Street
# E Chicago St => East Chicago Street
# Main St => Main Street
# Rose St => Rose Street
# Park St => Park Street
# Kathleen St => Kathleen Street
# N Ellsworth St => North Ellsworth Street
# Towne St => Towne Street
# Watch St => Watch Street
# Deborah St => Deborah Street
# Short St => Short Street
# W 111 St => West 111 Street
# W Main St => West Main Street
# W Lockport St => West Lockport Street
# Division St => Division Street
# W Patterson St => West Patterson Street
# S State St => South Southtate Southt
# Raymond St => Raymond Street
# W Maple St => West Maple Street
# W Chicago St => West Chicago Street
# W 183rd St => West 183rd Street
# N Railroad St => North Railroad Street
# Webster St => Webster Street
# W 18th St => West 18th Street
# Cross St => Cross Street
# N Division St => North Division Street
# State St => Streetate Street
# Liberty St => Liberty Street
# W Monroe St => West Monroe Street
# W Somonauk St => West Somonauk Street
# S 5th St => South 5th Southt
# S Bridge St => South Bridge Southt
# Lillie St => Lillie Street
# W High St => West High Street
# S 1st St => South 1st Southt
# Garden St => Garden Street
# S Gilbert St => South Gilbert Southt
# Kildare St => Kildare Street
# Railroad St => Railroad Street
# Suzanne St => Suzanne Street
# N Main St => North Main Street
# W Lake St => West Lake Street
# N Broadway St => North Broadway Street
# West Lake St => West Lake Street
# Nequa St => Nequa Street
# Welch St => Welch Street
# Tipperary St => Tipperary Street
# Dempster St => Dempster Street
# Pierce St => Pierce Street
# Pennsylvania St => Pennsylvania Street
# IL-53 => IL-53
# Red Hawk Path => Red Hawk Path
# Shining Moon Path => Shining Moon Path
# U.S. 14 => U.S. 14
# Route 14 => Route 14
# Millsfell => Millsfell
# roosevelt => roosevelt
# North River Walk => North River Walk
# W. Harrison => West Harrison
# N Lincoln Ave => North Lincoln Avenue
# South Gary Ave => South Gary Avenue
# South Cicero Ave => South Cicero Avenue
# W Park Ave => West Park Avenue
# S Western Ave => South Western Avenue
# N. Glenwood Ave => North Glenwood Avenue
# Dundee Ave => Dundee Avenue
# North Edgebrook Terrace => North Edgebrook Terrace
# South Park Terrace => South Park Terrace
# Colfax Terrace => Colfax Terrace
# Ridge Terrace => Ridge Terrace
# Barclay Blvd => Barclay Boulevard
# Naper Blvd => Naper Boulevard
# Sauk Blvd => Sauk Boulevard
# Potawatomi Blvd => Potawatomi Boulevard
# Oakwood Blvd => Oakwood Boulevard
# Hansen Blvd => Hansen Boulevard
# Timber Trails Blvd => Timber Trails Boulevard
# Patriot Blvd => Patriot Boulevard
# Grand Blvd => Grand Boulevard
# S Kenilworth Blvd => South Kenilworth Boulevard
# Franklin Blvd => Franklin Boulevard
# Sibley Blvd => Sibley Boulevard
# Shabbona => Shabbona
# Pass

# %% [markdown]
# # Data Setup

# %%
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:
{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}
You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB. You could also do some cleaning
before doing that, like in the previous exercise, but for this exercise you just have to
shape the structure.
In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings.
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:
<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>
  should be turned into:
{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}
- for "way" specifically:
  <nd ref="305896090"/>
  <nd ref="1719825889"/>
should be turned into
"node_ref": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
addresschars = re.compile(r'addr:(\w+)')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def shape_element(element):
    #node = defaultdict(set)
    node = {}
    if element.tag == "node" or element.tag == "way" :
        #create the dictionary based on exaclty the value in element attribute.
        node = {'created':{}, 'type':element.tag}
        for k in element.attrib:
            try:
                v = element.attrib[k]
            except KeyError:
                continue
            if k == 'lat' or k == 'lon':
                continue
            if k in CREATED:
                node['created'][k] = v
            else:
                node[k] = v
        try:
            node['pos']=[float(element.attrib['lat']),float(element.attrib['lon'])]
        except KeyError:
            pass
        
        if 'address' not in node.keys():
            node['address'] = {}
        #Iterate the content of the tag
        for stag in element.iter('tag'):
            #Init the dictionry

            k = stag.attrib['k']
            v = stag.attrib['v']
            #Checking if indeed prefix with 'addr' and no ':' afterwards
            if k.startswith('addr:'):
                if len(k.split(':')) == 2:
                    content = addresschars.search(k)
                    if content:
                        node['address'][content.group(1)] = v
            else:
                node[k]=v
        if not node['address']:
            node.pop('address',None)
        #Special case when the tag == way,  scrap all the nd key
        if element.tag == "way":
            node['node_refs'] = []
            for nd in element.iter('nd'):
                node['node_refs'].append(nd.attrib['ref'])
#         if  'address' in node.keys():
#             pprint.pprint(node['address'])
        return node
    else:
        return None
    
def process_map(file_in, pretty = False):
    """
    Process the osm file to json file to be prepared for input file to monggo
    """
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
OSM_data = process_map(OSM_FILE)

# %%
pprint.pprint(OSM_data[0:6])
# Out:
# [{'_id': ObjectId('58079e975536b53cabe049db'),
#   'created': {'changeset': '7781188',
#               'timestamp': '2011-04-06T05:17:15Z',
#               'uid': '207745',
#               'user': 'NE2',
#               'version': '54'},
#   'exit_to': 'Joliet Road',
#   'highway': 'motorway_junction',
#   'id': '219850',
#   'pos': [41.7585879, -87.9101245],
#   'ref': '276C',
#   'type': 'node'},
#  {'_id': ObjectId('58079e975536b53cabe049dc'),
#   'created': {'changeset': '7781188',
#               'timestamp': '2011-04-06T05:18:47Z',
#               'uid': '207745',
#               'user': 'NE2',
#               'version': '47'},
#   'exit_to': 'North I-294 ; Tri-State Tollway;  Wisconsin',
#   'highway': 'motorway_junction',
#   'id': '219851',
#   'pos': [41.7593116, -87.9076432],
#   'ref': '277A',
#   'type': 'node'},
#  {'_id': ObjectId('58079e975536b53cabe049dd'),
#   'created': {'changeset': '485405',
#               'timestamp': '2009-04-13T11:21:51Z',
#               'uid': '18480',
#               'user': 'nickvet419',
#               'version': '14'},
#   'id': '700724',
#   'pos': [41.7120272, -88.0158606],
#   'type': 'node'},
#  {'_id': ObjectId('58079e975536b53cabe049de'),
#   'created': {'changeset': '485405',
#               'timestamp': '2009-04-13T11:21:51Z',
#               'uid': '18480',
#               'user': 'nickvet419',
#               'version': '14'},
#   'id': '700725',
#   'pos': [41.7142377, -88.0116119],
#   'type': 'node'},
#  {'_id': ObjectId('58079e975536b53cabe049df'),
#   'created': {'changeset': '240380',
#               'timestamp': '2007-03-20T02:56:54Z',
#               'uid': '5788',
#               'user': 'cluening',
#               'version': '1'},
#   'created_by': 'YahooApplet 1.0',
#   'id': '700726',
#   'pos': [41.716384, -88.007417],
#   'type': 'node'},
#  {'_id': ObjectId('58079e975536b53cabe049e0'),
#   'created': {'changeset': '3658',
#               'timestamp': '2006-04-14T21:00:21Z',
#               'uid': '229',
#               'user': 'LA2',
#               'version': '1'},
#   'id': '700727',
#   'pos': [41.7154871, -88.0091658],
#   'type': 'node'}]

# %%
client = MongoClient('localhost', 27017)

# %%
db = client.Final_osm

# %%
db.osm_final.insert(OSM_data)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#
# %%
#Testing find method
def find():
    nodes = db.osm_final.find({'id':'219850'})
    for a in nodes:
        pprint.pprint(a)
        
find()
# Out:
# {u'_id': ObjectId('58079e975536b53cabe049db'),
#  u'created': {u'changeset': u'7781188',
#               u'timestamp': u'2011-04-06T05:17:15Z',
#               u'uid': u'207745',
#               u'user': u'NE2',
#               u'version': u'54'},
#  u'exit_to': u'Joliet Road',
#  u'highway': u'motorway_junction',
#  u'id': u'219850',
#  u'pos': [41.7585879, -87.9101245],
#  u'ref': u'276C',
#  u'type': u'node'}

# %%
#Show 5 data that have street
def street_5():
    result  = db.osm_final.aggregate([
            {'$match': {'address.street':{'$exists':1}}},
            {'$limit' : 5}
        ])
    for a in result:
        pprint.pprint(a)

street_5()
# Out:
# {u'_id': ObjectId('58079eb05536b53cabe57cfa'),
#  u'address': {u'city': u'Evanston',
#               u'housenumber': u'1022',
#               u'postcode': u'60201',
#               u'street': u'Central Street'},
#  u'created': {u'changeset': u'34237971',
#               u'timestamp': u'2015-09-25T04:19:04Z',
#               u'uid': u'185986',
#               u'user': u'jonwchgo',
#               u'version': u'9'},
#  u'id': u'249656713',
#  u'name': u'Central',
#  u'network': u'CTA',
#  u'operator': u'Chicago Transit Authority',
#  u'pos': [42.064201, -87.685828],
#  u'railway': u'station',
#  u'type': u'node',
#  u'website': u'http://www.transitchicago.com/travel_information/station.aspx?StopId=34',
#  u'wheelchair': u'no',
#  u'wikipedia': u'en:Central (CTA Purple Line station)'}
# {u'_id': ObjectId('58079eb05536b53cabe58bea'),
#  u'address': {u'city': u'Chicago',
#               u'housenumber': u'1358',
#               u'postcode': u'60626',
#               u'state': u'IL',
#               u'street': u'West Morse Avenue'},
#  u'created': {u'changeset': u'35818420',
#               u'timestamp': u'2015-12-08T00:33:02Z',
#               u'uid': u'1237170',
#               u'user': u'Zol87',
#               u'version': u'14'},
#  u'id': u'252643581',
#  u'name': u'Morse',
#  u'network': u'CTA',
#  u'operator': u'Chicago Transit Authority',
#  u'pos': [42.0080864, -87.6659686],
#  u'public_transport': u'station',
#  u'railway': u'station',
#  u'type': u'node',
#  u'website': u'http://www.transitchicago.com/travel_information/station.aspx?StopId=104',
#  u'wheelchair': u'no',
#  u'wikipedia': u'en:Morse (CTA station)'}
# {u'_id': ObjectId('58079eb05536b53cabe58bf9'),
#  u'address': {u'housenumber': u'3940', u'street': u'North Sheridan Road'},
#  u'chicago:building_id': u'843356',
#  u'created': {u'changeset': u'15380077',
#               u'timestamp': u'2013-03-16T04:01:00Z',
#               u'uid': u'674454',
#               u'user': u'chicago-buildings',
#               u'version': u'12'},
#  u'id': u'252643632',
#  u'name': u'Sheridan',
#  u'operator': u'Chicago Transit Authority',
#  u'pos': [41.9538873, -87.654928],
#  u'railway': u'station',
#  u'type': u'node',
#  u'wheelchair': u'no'}
# {u'_id': ObjectId('58079eb05536b53cabe58bfa'),
#  u'address': {u'city': u'Chicago',
#               u'housenumber': u'940',
#               u'postcode': u'60613',
#               u'street': u'West Addison Street'},
#  u'chicago:building_id': u'174133',
#  u'created': {u'changeset': u'21658094',
#               u'timestamp': u'2014-04-13T05:39:18Z',
#               u'uid': u'1237170',
#               u'user': u'Zol87',
#               u'version': u'14'},
#  u'id': u'252683058',
#  u'name': u'Addison',
#  u'operator': u'Chicago Transit Authority',
#  u'pos': [41.9475198, -87.6536271],
#  u'public_transport': u'station',
#  u'railway': u'station',
#  u'type': u'node',
#  u'website': u'http://www.transitchicago.com/travel_information/station.aspx?StopId=17',
#  u'wheelchair': u'yes',
#  u'wikipedia': u'en:Addison (CTA Red Line station)'}
# {u'_id': ObjectId('58079eb15536b53cabe5998e'),
#  u'address': {u'housenumber': u'430', u'street': u'South Racine Avenue'},
#  u'chicago:building_id': u'363198',
#  u'created': {u'changeset': u'34429524',
#               u'timestamp': u'2015-10-04T15:01:13Z',
#               u'uid': u'672536',
#               u'user': u'xmd5a',
#               u'version': u'7'},
#  u'id': u'258026055',
#  u'name': u'Racine',
#  u'operator': u'Chicago Transit Authority',
#  u'pos': [41.8758843, -87.6593253],
#  u'railway': u'station',
#  u'station': u'subway',
#  u'type': u'node',
#  u'wheelchair': u'yes'}

# %%
#Examine make up of postal codes

def postal_codes():
    result  = db.osm_final.aggregate([{"$match":{"address.postcode":{"$exists":1}}}, 
                   {"$group":{"_id":"$address.postcode", "count":{"$sum":1}}}, 
                   {"$sort":{"count":1}}])
    for a in result:
        pprint.pprint(a)

postal_codes()
# Out:
# {u'_id': u'46373', u'count': 1}
# {u'_id': u'60487', u'count': 1}
# {u'_id': u'60425', u'count': 1}
# {u'_id': u'60409-9998', u'count': 1}
# {u'_id': u'60191-1983', u'count': 1}
# {u'_id': u'60827-6427', u'count': 1}
# {u'_id': u'6051', u'count': 1}
# {u'_id': u'Il', u'count': 1}
# {u'_id': u'606', u'count': 1}
# {u'_id': u'60203', u'count': 1}
# {u'_id': u'46404', u'count': 1}
# {u'_id': u'60712-2716', u'count': 1}
# {u'_id': u'60654-5799', u'count': 1}
# {u'_id': u'60627', u'count': 1}
# {u'_id': u'60016-5670', u'count': 1}
# {u'_id': u'60016-5608', u'count': 1}
# {u'_id': u'46406', u'count': 1}
# {u'_id': u'601412', u'count': 1}
# {u'_id': u'60521-2101', u'count': 1}
# {u'_id': u'IL 60605-1226', u'count': 1}
# {u'_id': u'60422', u'count': 1}
# {u'_id': u'60469', u'count': 1}
# {u'_id': u'60483', u'count': 1}
# {u'_id': u'60401', u'count': 1}
# {u'_id': u'0201', u'count': 1}
# {u'_id': u'60696', u'count': 1}
# {u'_id': u'60076-2000', u'count': 1}
# {u'_id': u'60546-1262', u'count': 1}
# {u'_id': u'60077-3495', u'count': 1}
# {u'_id': u'IL 60707', u'count': 1}
# {u'_id': u'46411', u'count': 1}
# {u'_id': u'60077-1314', u'count': 1}
# {u'_id': u'IL 60118', u'count': 1}
# {u'_id': u'60185-4419', u'count': 1}
# {u'_id': u'60151', u'count': 1}
# {u'_id': u'60504-7276', u'count': 1}
# {u'_id': u'IL, 60126', u'count': 1}
# {u'_id': u'IL, 60642', u'count': 1}
# {u'_id': u'60622-4580', u'count': 1}
# {u'_id': u'60614 ', u'count': 1}
# {u'_id': u'6074', u'count': 1}
# {u'_id': u'60069-3137', u'count': 1}
# {u'_id': u'2300', u'count': 1}
# {u'_id': u'60415', u'count': 1}
# {u'_id': u'60022-1525', u'count': 1}
# {u'_id': u'60456', u'count': 1}
# {u'_id': u'60139', u'count': 1}
# {u'_id': u'37419', u'count': 1}
# {u'_id': u'60007-3545', u'count': 1}
# {u'_id': u'60160-1607', u'count': 1}
# {u'_id': u'60432', u'count': 1}
# {u'_id': u'60461', u'count': 1}
# {u'_id': u'60022-1941', u'count': 1}
# {u'_id': u'60538', u'count': 1}
# {u'_id': u'60586', u'count': 1}
# {u'_id': u'60434', u'count': 1}
# {u'_id': u'46410-5468', u'count': 1}
# {u'_id': u'46319', u'count': 1}
# {u'_id': u'60064', u'count': 1}
# {u'_id': u'60056-5712', u'count': 1}
# {u'_id': u'60513-9998', u'count': 1}
# {u'_id': u'60503', u'count': 1}
# {u'_id': u'60615-5299', u'count': 1}
# {u'_id': u'60428', u'count': 1}
# {u'_id': u'60475', u'count': 1}
# {u'_id': u'Wasco, IL  60183', u'count': 1}
# {u'_id': u'60440-1412', u'count': 1}
# {u'_id': u'60660-4199', u'count': 1}
# {u'_id': u'60478', u'count': 1}
# {u'_id': u'46341', u'count': 1}
# {u'_id': u'60021', u'count': 1}
# {u'_id': u'6007', u'count': 1}
# {u'_id': u'60018-2627', u'count': 1}
# {u'_id': u'60666', u'count': 2}
# {u'_id': u'65027', u'count': 2}
# {u'_id': u'60448', u'count': 2}
# {u'_id': u'60445', u'count': 2}
# {u'_id': u'60437', u'count': 2}
# {u'_id': u'60419', u'count': 2}
# {u'_id': u'60029', u'count': 2}
# {u'_id': u'60466', u'count': 2}
# {u'_id': u'60403', u'count': 2}
# {u'_id': u'60484', u'count': 2}
# {u'_id': u'60458', u'count': 2}
# {u'_id': u'IL', u'count': 2}
# {u'_id': u'Wasco, IL 60183', u'count': 2}
# {u'_id': u'60480', u'count': 2}
# {u'_id': u'60534', u'count': 2}
# {u'_id': u'60513', u'count': 2}
# {u'_id': u'60189-8172', u'count': 2}
# {u'_id': u'61341', u'count': 2}
# {u'_id': u'60526', u'count': 2}
# {u'_id': u'60183', u'count': 2}
# {u'_id': u'60514', u'count': 2}
# {u'_id': u'60084', u'count': 2}
# {u'_id': u'60455', u'count': 2}
# {u'_id': u'60183 / 60174', u'count': 2}
# {u'_id': u'60542', u'count': 2}
# {u'_id': u'46405', u'count': 2}
# {u'_id': u'60133', u'count': 2}
# {u'_id': u'46375', u'count': 3}
# {u'_id': u'60565', u'count': 3}
# {u'_id': u'60013', u'count': 3}
# {u'_id': u'60429', u'count': 3}
# {u'_id': u'60040', u'count': 3}
# {u'_id': u'60404', u'count': 3}
# {u'_id': u'60012', u'count': 3}
# {u'_id': u'60473', u'count': 3}
# {u'_id': u'46368', u'count': 3}
# {u'_id': u'60501', u'count': 4}
# {u'_id': u'60652', u'count': 4}
# {u'_id': u'60459', u'count': 4}
# {u'_id': u'60564', u'count': 4}
# {u'_id': u'60655', u'count': 4}
# {u'_id': u'46304', u'count': 4}
# {u'_id': u'60646', u'count': 4}
# {u'_id': u'60119', u'count': 4}
# {u'_id': u'60417', u'count': 4}
# {u'_id': u'60426', u'count': 4}
# {u'_id': u'60633', u'count': 4}
# {u'_id': u'60435', u'count': 4}
# {u'_id': u'46410', u'count': 4}
# {u'_id': u'60192', u'count': 4}
# {u'_id': u'60172', u'count': 5}
# {u'_id': u'60558', u'count': 5}
# {u'_id': u'60162', u'count': 5}
# {u'_id': u'60585', u'count': 5}
# {u'_id': u'60559', u'count': 5}
# {u'_id': u'46403', u'count': 5}
# {u'_id': u'60544', u'count': 5}
# {u'_id': u'60477', u'count': 5}
# {u'_id': u'60827', u'count': 5}
# {u'_id': u'60464', u'count': 5}
# {u'_id': u'60502', u'count': 6}
# {u'_id': u'60154', u'count': 6}
# {u'_id': u'60431', u'count': 6}
# {u'_id': u'60442', u'count': 6}
# {u'_id': u'46311', u'count': 6}
# {u'_id': u'60453', u'count': 6}
# {u'_id': u'60156', u'count': 6}
# {u'_id': u'60452', u'count': 6}
# {u'_id': u'60103', u'count': 6}
# {u'_id': u'60177', u'count': 6}
# {u'_id': u'60069', u'count': 6}
# {u'_id': u'46394', u'count': 6}
# {u'_id': u'60033', u'count': 7}
# {u'_id': u'46303', u'count': 7}
# {u'_id': u'60301', u'count': 7}
# {u'_id': u'60516', u'count': 7}
# {u'_id': u'60543', u'count': 7}
# {u'_id': u'60110', u'count': 7}
# {u'_id': u'60190', u'count': 7}
# {u'_id': u'60070', u'count': 8}
# {u'_id': u'60651', u'count': 8}
# {u'_id': u'46320', u'count': 8}
# {u'_id': u'60803', u'count': 8}
# {u'_id': u'60451', u'count': 8}
# {u'_id': u'60155', u'count': 9}
# {u'_id': u'60491', u'count': 9}
# {u'_id': u'60636', u'count': 9}
# {u'_id': u'60044', u'count': 9}
# {u'_id': u'60108', u'count': 9}
# {u'_id': u'60410', u'count': 9}
# {u'_id': u'60060', u'count': 9}
# {u'_id': u'60409', u'count': 10}
# {u'_id': u'60022', u'count': 10}
# {u'_id': u'60430', u'count': 10}
# {u'_id': u'60406', u'count': 10}
# {u'_id': u'60165', u'count': 10}
# {u'_id': u'60101', u'count': 10}
# {u'_id': u'60045', u'count': 10}
# {u'_id': u'60463', u'count': 11}
# {u'_id': u'60441', u'count': 11}
# {u'_id': u'60061', u'count': 11}
# {u'_id': u'60490', u'count': 11}
# {u'_id': u'60555', u'count': 11}
# {u'_id': u'60506', u'count': 12}
# {u'_id': u'60629', u'count': 12}
# {u'_id': u'60449', u'count': 12}
# {u'_id': u'46307', u'count': 12}
# {u'_id': u'60644', u'count': 12}
# {u'_id': u'60124', u'count': 12}
# {u'_id': u'60712', u'count': 12}
# {u'_id': u'60163', u'count': 13}
# {u'_id': u'60068', u'count': 13}
# {u'_id': u'60450', u'count': 13}
# {u'_id': u'60561', u'count': 13}
# {u'_id': u'60554', u'count': 13}
# {u'_id': u'60628', u'count': 14}
# {u'_id': u'60134', u'count': 50}
# {u'_id': u'46327', u'count': 51}
# {u'_id': u'60640', u'count': 51}
# {u'_id': u'60643', u'count': 51}
# {u'_id': u'60546', u'count': 53}
# {u'_id': u'46324', u'count': 55}
# {u'_id': u'60616', u'count': 56}
# {u'_id': u'60440', u'count': 59}
# {u'_id': u'60608', u'count': 59}
# {u'_id': u'60510', u'count': 60}
# {u'_id': u'60181', u'count': 60}
# {u'_id': u'60195', u'count': 60}
# {u'_id': u'60191', u'count': 62}
# {u'_id': u'60610', u'count': 62}
# {u'_id': u'60104', u'count': 64}
# {u'_id': u'60130', u'count': 64}
# {u'_id': u'60626', u'count': 65}
# {u'_id': u'46321', u'count': 68}
# {u'_id': u'60657', u'count': 70}
# {u'_id': u'60208', u'count': 70}
# {u'_id': u'60631', u'count': 73}
# {u'_id': u'60439', u'count': 74}
# {u'_id': u'60411', u'count': 75}
# {u'_id': u'60515', u'count': 75}
# {u'_id': u'60661', u'count': 76}
# {u'_id': u'60647', u'count': 78}
# {u'_id': u'60142', u'count': 79}
# {u'_id': u'60107', u'count': 80}
# {u'_id': u'60603', u'count': 82}
# {u'_id': u'60074', u'count': 84}
# {u'_id': u'60622', u'count': 87}
# {u'_id': u'60160', u'count': 88}
# {u'_id': u'60618', u'count': 90}
# {u'_id': u'60193', u'count': 91}
# {u'_id': u'60126', u'count': 93}
# {u'_id': u'60153', u'count': 95}
# {u'_id': u'60077', u'count': 95}
# {u'_id': u'60016', u'count': 96}
# {u'_id': u'60606', u'count': 99}
# {u'_id': u'60091', u'count': 103}
# {u'_id': u'60525', u'count': 106}
# {u'_id': u'60194', u'count': 108}
# {u'_id': u'60176', u'count': 112}
# {u'_id': u'60601', u'count': 123}
# {u'_id': u'60062', u'count': 134}
# {u'_id': u'60093', u'count': 136}
# {u'_id': u'60025', u'count': 139}
# {u'_id': u'60607', u'count': 149}
# {u'_id': u'60131', u'count': 153}
# {u'_id': u'60614', u'count': 155}
# {u'_id': u'60654', u'count': 164}
# {u'_id': u'60076', u'count': 167}
# {u'_id': u'60007', u'count': 169}
# {u'_id': u'60018', u'count': 207}
# {u'_id': u'60164', u'count': 208}
# {u'_id': u'60173', u'count': 214}
# {u'_id': u'60630', u'count': 223}
# {u'_id': u'46385', u'count': 226}
# {u'_id': u'60067', u'count': 233}
# {u'_id': u'60611', u'count': 251}
# {u'_id': u'60056', u'count': 251}
# {u'_id': u'60605', u'count': 254}
# {u'_id': u'60008', u'count': 282}
# {u'_id': u'60005', u'count': 363}
# {u'_id': u'60004', u'count': 383}
# {u'_id': u'60615', u'count': 384}
# {u'_id': u'60521', u'count': 409}
# {u'_id': u'60148', u'count': 729}
# {u'_id': u'60637', u'count': 859}
# {u'_id': u'60089', u'count': 864}
# {u'_id': u'60136', u'count': 1306}
# {u'_id': u'60305', u'count': 1719}
# {u'_id': u'60202', u'count': 7725}
# {u'_id': u'60201', u'count': 9389}

# %%
#Show the top 5 of contributed users
def users_5():
    result  = db.osm_final.aggregate([
            {'$match': {'created.user':{'$exists':1}}},
            {'$group': {'_id':'$created.user',
                        'count':{'$sum':1}}},
            {'$sort': {'count':-1}},
            {'$limit' : 5}
        ])
    for a in result:
        pprint.pprint(a)

users_5()
# Out:
# {u'_id': u'chicago-buildings', u'count': 5635534}
# {u'_id': u'Umbugbene', u'count': 1101042}
# {u'_id': u'alexrudd (NHD)', u'count': 232740}
# {u'_id': u'woodpeck_fixbot', u'count': 225702}
# {u'_id': u'patester24', u'count': 109091}

# %%
#Show the restaurant's name, the food they serve, and contact number

def restaurant_5():
    result  = db.osm_final.aggregate([
           {'$match': {'amenity':'restaurant',
                        'name':{'$exists':1}}},
            {'$project':{'_id':'$name',
                         'cuisine':'$cuisine',
                         'contact':'$phone'}}
        ])
    for a in result:
        pprint.pprint(a)

restaurant_5()
# Out:
# {u'_id': u'Coffee Beanery'}
# {u'_id': u'Panera Bread', u'cuisine': u'sandwich'}
# {u'_id': u'Char House Grill', u'cuisine': u'burger'}
# {u'_id': u"Clarke's", u'cuisine': u'burger'}
# {u'_id': u"Chili's", u'cuisine': u'southwest'}
# {u'_id': u'Bubba Gump Shrimp Co.'}
# {u'_id': u"Capi's Italian Kitchen"}
# {u'_id': u"Ada's Famous Deli & Restaurant"}
# {u'_id': u'Outback', u'cuisine': u'steak_house'}
# {u'_id': u"Winberie's"}
# {u'_id': u'Yen Yen', u'cuisine': u'Cantonese;American'}
# {u'_id': u'Pompei Pizza & Pasta',
#  u'contact': u'847-259-056',
#  u'cuisine': u'italian'}
# {u'_id': u"Domino's Pizza"}
# {u'_id': u'Sushi Kamon', u'cuisine': u'Sushi;Japanese'}
# {u'_id': u'Hotshots'}
# {u'_id': u'Baskin 31 Robbins'}
# {u'_id': u'Buffalo'}
# {u'_id': u"Branko's Submarines", u'cuisine': u'burger'}
# {u'_id': u"Portillo's", u'contact': u'847-933-0700', u'cuisine': u'sandwich'}
# {u'_id': u'Village Inn Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Pizano's Pizza & Pasta", u'cuisine': u'pizza;pasta'}
# {u'_id': u"Portillo's Hot Dogs"}
# {u'_id': u'Clark St Dog'}
# {u'_id': u'Rose Angelis', u'cuisine': u'italian'}
# {u'_id': u"Lou Malnati's", u'cuisine': u'pizza'}
# {u'_id': u'La Amistad', u'cuisine': u'mexican'}
# {u'_id': u'Twin Anchors'}
# {u'_id': u'Chuck-e-Cheeses'}
# {u'_id': u'Outback Steakhouse'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u'Shallots Bistro', u'cuisine': u'international'}
# {u'_id': u'Eleven City Diner'}
# {u'_id': u'Amici', u'cuisine': u'italian'}
# {u'_id': u'Bakers Square', u'cuisine': u'burger; pie'}
# {u'_id': u'Da Nella', u'cuisine': u'pizza'}
# {u'_id': u'The Berghoff'}
# {u'_id': u'Shui Wah'}
# {u'_id': u'The Noodle', u'cuisine': u'italian'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Kamakura', u'cuisine': u'japanese'}
# {u'_id': u"Domino's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Red Robin'}
# {u'_id': u"Tapia's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"ZaZa's"}
# {u'_id': u'La Canasta Grill'}
# {u'_id': u'Duck Walk'}
# {u'_id': u'Au Cheval', u'cuisine': u'upscale_"diner"'}
# {u'_id': u'Sushi Pink', u'cuisine': u'japanese'}
# {u'_id': u'Perez Restaurant', u'cuisine': u'mexican'}
# {u'_id': u'Westfield Family Restaurant'}
# {u'_id': u'Golden Apple', u'contact': u'773-528-1413'}
# {u'_id': u'Flat Top Grill', u'cuisine': u'asian'}
# {u'_id': u'Sapore di Napoli'}
# {u'_id': u'Bentonara', u'cuisine': u'japanese'}
# {u'_id': u'Giordanos'}
# {u'_id': u"Maciano's Pizza"}
# {u'_id': u"Chili's"}
# {u'_id': u'Metro'}
# {u'_id': u"Applebee's"}
# {u'_id': u'Pizza Hut'}
# {u'_id': u'Red Lobster'}
# {u'_id': u'Tiki Terrace'}
# {u'_id': u"Harry Caray's Italian Steakhouse"}
# {u'_id': u'Longhorn Steakhouse'}
# {u'_id': u'The Choo Choo Diner', u'cuisine': u'american'}
# {u'_id': u'Sugar Bowl'}
# {u'_id': u'En Lai Chinese Restaurant'}
# {u'_id': u'Ghareeb Nawaz', u'cuisine': u'indian'}
# {u'_id': u'Bar Louie', u'contact': u'847-733-8300'}
# {u'_id': u'Tapas Barcelona', u'cuisine': u'mexican'}
# {u'_id': u'Boltwood'}
# {u'_id': u"Buffalo Joe's", u'contact': u'847-328-5525'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Flat Top Grill', u'contact': u'847-570-0100'}
# {u'_id': u'Chipotle'}
# {u'_id': u'Cosi'}
# {u'_id': u"Lou Malnati's"}
# {u'_id': u'Joy Yee Noodles',
#  u'contact': u'847-733-1900',
#  u'cuisine': u'chinese'}
# {u'_id': u"Lulu's", u'cuisine': u'asian'}
# {u'_id': u'Koi', u'cuisine': u'asian'}
# {u'_id': u'Mt. Everest'}
# {u'_id': u"Giordano's", u'cuisine': u'pizza'}
# {u'_id': u'Le Peep', u'cuisine': u'breakfast'}
# {u'_id': u'Dixie Kitchen', u'contact': u'847-733-9030'}
# {u'_id': u'International House Of Pancakes'}
# {u'_id': u'Buffet King'}
# {u'_id': u"Clara's"}
# {u'_id': u'Superossa'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u"Hackney's", u'contact': u'(312)-1116', u'cuisine': u'western'}
# {u'_id': u"Cemeno's Pizza"}
# {u'_id': u"Nick's Fishmarket"}
# {u'_id': u"Chili's"}
# {u'_id': u"Aurelio's Pizza"}
# {u'_id': u'La Mex'}
# {u'_id': u'Tapalpa', u'contact': u'+1-847-956-9411'}
# {u'_id': u'Lonestar Restaurant'}
# {u'_id': u"Al's Steak House"}
# {u'_id': u'Golden Corral'}
# {u'_id': u'Old Fashioned Pancake House'}
# {u'_id': u"Stella's Diner"}
# {u'_id': u'Ann Sather'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u'Mr. Beef and Pizza'}
# {u'_id': u'Stadium Sports Club and Pizza'}
# {u'_id': u"Brown's Chicken and Pasta"}
# {u'_id': u'Chef of Siam'}
# {u'_id': u'San Soo Gab San', u'cuisine': u'korean, sushi, japanese'}
# {u'_id': u'Tre Kronor', u'cuisine': u'swedish'}
# {u'_id': u"Mickey Finn's Brewery"}
# {u'_id': u'Townee Square'}
# {u'_id': u'Picnic Basket'}
# {u'_id': u'Casa Bonita'}
# {u'_id': u'The Tavern'}
# {u'_id': u'Palmer Place'}
# {u'_id': u'Jamaica Jerk'}
# {u'_id': u'Kit Kat Club', u'cuisine': u'american'}
# {u'_id': u'Waffles'}
# {u'_id': u"Angelina's Italian Restaurant"}
# {u'_id': u'Melrose Diner', u'cuisine': u'diner'}
# {u'_id': u'Ping Pong Asian-Thai'}
# {u'_id': u'IHOP'}
# {u'_id': u'IHOP', u'cuisine': u'american'}
# {u'_id': u'Las Mananitas', u'contact': u'+1-773-528-2109'}
# {u'_id': u"Nookie's"}
# {u'_id': u"Gino's East", u'contact': u'+1 773 4442244', u'cuisine': u'pizza'}
# {u'_id': u'Los Dos Compadres',
#  u'contact': u'(847)455-5990',
#  u'cuisine': u'mexican'}
# {u'_id': u'Boston Market'}
# {u'_id': u'Trattoria Oliveri'}
# {u'_id': u'Landmark Inn'}
# {u'_id': u"Butterfield's"}
# {u'_id': u"Marisa's"}
# {u'_id': u"Puree's Pizza"}
# {u'_id': u'Dear Franks', u'cuisine': u'burger'}
# {u'_id': u"Ino's Pizzeria",
#  u'contact': u'773-275-8830',
#  u'cuisine': u'italian'}
# {u'_id': u'Huaraches Dona Chio Mexican restaurant'}
# {u'_id': u"mother's", u'cuisine': u'other'}
# {u'_id': u'Panda Express', u'cuisine': u'chinese'}
# {u'_id': u'Bar Louie'}
# {u'_id': u'South Loop Club'}
# {u'_id': u"Mindy's"}
# {u'_id': u"Morgan's"}
# {u'_id': u"Denny's"}
# {u'_id': u'Taqueria La Penca', u'cuisine': u'mexican'}
# {u'_id': u'2 Amigos', u'cuisine': u'mexican'}
# {u'_id': u'Furious Spoon', u'cuisine': u'ramen'}
# {u'_id': u'BurntToast Restaurant', u'contact': u'(847) 854-9552'}
# {u'_id': u"Elly's Pancake House",
#  u'contact': u'(847)364-4400',
#  u'cuisine': u'american'}
# {u'_id': u"Dunkin' Donuts", u'cuisine': u'american'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'Altiro Latin Fusion', u'cuisine': u'mexican'}
# {u'_id': u'Pad Thai', u'cuisine': u'thai'}
# {u'_id': u'Jalasco Express', u'cuisine': u'mexican'}
# {u'_id': u'Flapjacks', u'cuisine': u'american'}
# {u'_id': u'Breakfast Club'}
# {u'_id': u'Cheeseburger in Paradise'}
# {u'_id': u'Bonefish Grill'}
# {u'_id': u"Glenn's Diner", u'cuisine': u'fish'}
# {u'_id': u"Budacki's", u'cuisine': u'burger'}
# {u'_id': u"Giordano's", u'cuisine': u'pizza'}
# {u'_id': u'El Torito', u'cuisine': u'mexican'}
# {u'_id': u"Chicago's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Bad Apple', u'cuisine': u'burger'}
# {u'_id': u'Spacca Napoli', u'cuisine': u'pizza'}
# {u'_id': u"Egg'lectic Caf\xe9"}
# {u'_id': u"Ray's", u'cuisine': u'american'}
# {u'_id': u'Delicia Cafe', u'cuisine': u'international'}
# {u'_id': u'Colonial Cafe', u'cuisine': u'american'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'El Faro', u'cuisine': u'mexican'}
# {u'_id': u'Outback Steakhouse', u'cuisine': u'steak_house'}
# {u'_id': u"Sergio's Cantina", u'cuisine': u'mexican'}
# {u'_id': u"Aurelio's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Front Street Cantina', u'cuisine': u'mexican'}
# {u'_id': u'Niche'}
# {u'_id': u'Nosh'}
# {u'_id': u'Red Lobster', u'cuisine': u'seafood'}
# {u'_id': u'Forever Yogurt', u'cuisine': u'ice_cream'}
# {u'_id': u"Fiora's", u'cuisine': u'american'}
# {u'_id': u'Gen Hoe', u'cuisine': u'chinese'}
# {u'_id': u"Denny's", u'cuisine': u'american'}
# {u'_id': u'House of Wings', u'cuisine': u'american'}
# {u'_id': u'Nine', u'cuisine': u'thai'}
# {u'_id': u'Tapas Restarurant/Bar', u'cuisine': u'international'}
# {u'_id': u'California Pizza Kitchen', u'cuisine': u'pizza'}
# {u'_id': u"Houlihan's"}
# {u'_id': u'Noodles & Company'}
# {u'_id': u"Lume's"}
# {u'_id': u'Eagle Restaurant', u'cuisine': u'american'}
# {u'_id': u'Dover Straits', u'cuisine': u'fish'}
# {u'_id': u'Tacos Locos'}
# {u'_id': u'Around The Clock'}
# {u'_id': u'Fork', u'cuisine': u'american'}
# {u'_id': u'Bad Dog Tavern'}
# {u'_id': u"Emma's Bagel Cafe", u'cuisine': u'bagel'}
# {u'_id': u"EJ's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Slice of Life / Hy Life Bistro', u'cuisine': u'french'}
# {u'_id': u"Larsa's Restaurant", u'cuisine': u'mediterranean'}
# {u'_id': u"Ken's Diner", u'cuisine': u'american'}
# {u'_id': u'El Tipico', u'cuisine': u'mexican'}
# {u'_id': u'Marmalade'}
# {u'_id': u"Monty Gael's", u'cuisine': u'american'}
# {u'_id': u'Roong Petch', u'cuisine': u'thai'}
# {u'_id': u'Burger King', u'cuisine': u'burger'}
# {u'_id': u'Subway'}
# {u'_id': u'Roti Mediterranean Grill'}
# {u'_id': u'Marquette Inn', u'cuisine': u'diner'}
# {u'_id': u'Bonsai Cafe', u'cuisine': u'asian'}
# {u'_id': u"Nick's Fishmarket Grill"}
# {u'_id': u'House of Szechwan', u'cuisine': u'asian'}
# {u'_id': u'Pizza Art Cafe'}
# {u'_id': u'Pasta Mai', u'cuisine': u'italian'}
# {u'_id': u'Daily Bar and Grill'}
# {u'_id': u'Essence of India', u'cuisine': u'indian'}
# {u'_id': u'Cafe Selmarie', u'cuisine': u'american'}
# {u'_id': u'Bistro Campagne', u'cuisine': u'french'}
# {u'_id': u'Gideon Welles'}
# {u'_id': u'Chicago Brauhaus', u'cuisine': u'german'}
# {u'_id': u'Apart Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Denny's", u'cuisine': u'american'}
# {u'_id': u"Chuck n' Cheese", u'cuisine': u'pizza'}
# {u'_id': u"Macciano's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Chan's Gourmet", u'cuisine': u'chinese'}
# {u'_id': u"Papa Saverio's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Einstein's Bagels"}
# {u'_id': u'Donut Den'}
# {u'_id': u'Belly Shack', u'contact': u'773-252-1414'}
# {u'_id': u'The Goddess and Grocer', u'cuisine': u'sandwich'}
# {u'_id': u'Soul del Sur', u'cuisine': u'mexican'}
# {u'_id': u'Via Roma'}
# {u'_id': u'Mexico', u'cuisine': u'mexican'}
# {u'_id': u'Bangkok Thai', u'cuisine': u'thai'}
# {u'_id': u'Brickhouse Pizza Pub', u'cuisine': u'pizza'}
# {u'_id': u"Porky's B.B.Q. Ribs"}
# {u'_id': u"Southern Belle's Pancake House"}
# {u'_id': u'MyThai Takumi', u'cuisine': u'thai'}
# {u'_id': u'Plymouth'}
# {u'_id': u"A's Restaurant & Pancake House", u'cuisine': u'american'}
# {u'_id': u"Chili's", u'cuisine': u'american'}
# {u'_id': u"Leona's"}
# {u'_id': u"Sultan's Market", u'cuisine': u'kebab'}
# {u'_id': u'Grahamwich', u'cuisine': u'sandwich'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'Lucky Platter'}
# {u'_id': u"Kuni's", u'contact': u'847-328-2004', u'cuisine': u'japanese'}
# {u'_id': u"Fraternelli's Pizza"}
# {u'_id': u'Pritzker Club'}
# {u'_id': u'BIN 36', u'cuisine': u'wine_bar'}
# {u'_id': u'Bang Chop Thai Kitchen', u'cuisine': u'thai'}
# {u'_id': u"Pazzo's"}
# {u'_id': u'Sbarro'}
# {u'_id': u'Subway'}
# {u'_id': u'The Pepper Canister'}
# {u'_id': u'Tio Luis'}
# {u'_id': u"Jack & Ginger's"}
# {u'_id': u'Le Bouchon', u'cuisine': u'french'}
# {u'_id': u'Milk and Honey Cafe'}
# {u'_id': u'El Cid #2'}
# {u'_id': u'Lula Cafe'}
# {u'_id': u"Dunkin' Donuts", u'cuisine': u'coffee_shop'}
# {u'_id': u'Des Plaines Family Restaurant & Pancake House',
#  u'cuisine': u'american'}
# {u'_id': u'Bobtail Ice Cream Company', u'cuisine': u'ice_cream'}
# {u'_id': u'The Village Squire'}
# {u'_id': u"TGI Friday's"}
# {u'_id': u"Portillo's"}
# {u'_id': u'Corner Bakery Cafe'}
# {u'_id': u'Outback Steakhouse'}
# {u'_id': u"Chuck E Cheese's"}
# {u'_id': u"Richard Walker's Pancake House"}
# {u'_id': u"Chilli's Bar & Grill"}
# {u'_id': u'Cary Resturant'}
# {u'_id': u'Due Lire', u'cuisine': u'italian'}
# {u'_id': u'Mixteco Grill', u'cuisine': u'mexican'}
# {u'_id': u'Caro Mio', u'cuisine': u'italian'}
# {u'_id': u'Fin', u'cuisine': u'sushi'}
# {u'_id': u'Rockit Burger Bar', u'cuisine': u'burger'}
# {u'_id': u'Spicy Bites', u'cuisine': u'indian'}
# {u'_id': u'Auroma Restaurent'}
# {u'_id': u'Dinotto', u'cuisine': u'pizza'}
# {u'_id': u'Einstein Bagels', u'cuisine': u'sandwich'}
# {u'_id': u'Wishbone', u'cuisine': u'southern'}
# {u'_id': u'Panda Chinese'}
# {u'_id': u'Island Lake Inn'}
# {u'_id': u"Jimmy John's", u'cuisine': u'sandwich'}
# {u'_id': u'Punta Cana', u'cuisine': u'dominican'}
# {u'_id': u'Piece Brewery & Pizzeria', u'cuisine': u'pizza'}
# {u'_id': u'Burrito Joint', u'cuisine': u'mexican'}
# {u'_id': u'Japan 77 Steak House', u'cuisine': u'japanese'}
# {u'_id': u'Hickory River Smokehouse', u'cuisine': u'american'}
# {u'_id': u'Pho Ha', u'cuisine': u'vietnamese'}
# {u'_id': u'Cross Rhodes', u'cuisine': u'greek'}
# {u'_id': u"Dondi's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Giordano's", u'cuisine': u'pizza'}
# {u'_id': u'Market Creations'}
# {u'_id': u'Wildberry Pancakes and Cafe',
#  u'contact': u'312-938-9777',
#  u'cuisine': u'breakfast'}
# {u'_id': u'Great Wall', u'cuisine': u'chinese'}
# {u'_id': u'Honey-Jam Cafe'}
# {u'_id': u'Bravo Cucina', u'contact': u'847-733-0917', u'cuisine': u'italian'}
# {u'_id': u'Hunan Spring Restaurant',
#  u'contact': u'847-328-8082',
#  u'cuisine': u'chinese'}
# {u'_id': u'Yum Cha Dim Sum Parlor',
#  u'contact': u'+1 312 946-8885',
#  u'cuisine': u'chinese'}
# {u'_id': u'The Alcove', u'cuisine': u'french'}
# {u'_id': u'Oceanique', u'cuisine': u'french'}
# {u'_id': u'Siam Paragon', u'cuisine': u'japanese'}
# {u'_id': u'Hilltop', u'cuisine': u'american'}
# {u'_id': u"Giordano's",
#  u'contact': u'(630) 762-1600',
#  u'cuisine': u'italian;pizza'}
# {u'_id': u"Portillo's", u'cuisine': u'american'}
# {u'_id': u'Cheescake Factory'}
# {u'_id': u'Pizza For U', u'cuisine': u'pizza'}
# {u'_id': u'Pizza Capri', u'cuisine': u'italian'}
# {u'_id': u'Mellow Yellow', u'cuisine': u'american'}
# {u'_id': u'Valois', u'cuisine': u'american'}
# {u'_id': u'Noodes & Company'}
# {u'_id': u'Cooba'}
# {u'_id': u'Sopo Lounge & Grill'}
# {u'_id': u'Kinzie Chop House', u'cuisine': u'steak_house'}
# {u'_id': u'Chicago Cut Steakhouse', u'cuisine': u'steak_house'}
# {u'_id': u'Davis Street Fish Market',
#  u'contact': u'847-869-3474',
#  u'cuisine': u'fish'}
# {u'_id': u"Dave's Italian Kitchen", u'contact': u'847-864-6000'}
# {u'_id': u'Olive Mountain'}
# {u'_id': u'Sandwich Me In', u'cuisine': u'sandwich'}
# {u'_id': u'Giordanos', u'cuisine': u'pizza'}
# {u'_id': u'India House', u'cuisine': u'indian'}
# {u'_id': u"Lallo's Bar and Grill", u'cuisine': u'mexican'}
# {u'_id': u'Lupitas', u'cuisine': u'mexican'}
# {u'_id': u"Lindy's Chili", u'cuisine': u'burger'}
# {u'_id': u'Huck Finn Restaurant'}
# {u'_id': u'La Palapa Mariscos', u'cuisine': u'fish,_Mexican,_seafood'}
# {u'_id': u'Taverna 750', u'cuisine': u'american'}
# {u'_id': u'Ann Sather'}
# {u'_id': u'Summer', u'cuisine': u'thai'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u'Revival Social Club', u'cuisine': u'american'}
# {u'_id': u"Gino's North", u'cuisine': u'pizza'}
# {u'_id': u"Pete's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Jimmy John's", u'cuisine': u'sandwich'}
# {u'_id': u'Sankalp', u'cuisine': u'indian'}
# {u'_id': u'Worri Village', u'cuisine': u'korean'}
# {u'_id': u'Ron of Japan', u'cuisine': u'japanese'}
# {u'_id': u'Noodles & Company', u'cuisine': u'noodle'}
# {u'_id': u'Ellys Pancake House',
#  u'contact': u'8476359500',
#  u'cuisine': u'breakfast'}
# {u'_id': u'Panda Express', u'cuisine': u'chinese'}
# {u'_id': u'Prosecco', u'cuisine': u'italian'}
# {u'_id': u"Chili's", u'contact': u'847-328-9068'}
# {u'_id': u'Terzo Piano', u'cuisine': u'italian'}
# {u'_id': u"Sam's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'City Of Champions Sports Bar'}
# {u'_id': u'Bakers Square'}
# {u'_id': u'Plainfield Pancake Delite', u'cuisine': u'american'}
# {u'_id': u'Melting Pot'}
# {u'_id': u'HomeMade Pizza Co.', u'cuisine': u'pizza'}
# {u'_id': u'Dozika'}
# {u'_id': u'Salam', u'cuisine': u'arab'}
# {u'_id': u'Farmhouse', u'contact': u'847-491-9220', u'cuisine': u'american'}
# {u'_id': u'Bistro Bordeaux',
#  u'contact': u'847-424-1483',
#  u'cuisine': u'french'}
# {u'_id': u"Edzo's Burger Shop",
#  u'contact': u'847-864-EDZO',
#  u'cuisine': u'burger'}
# {u'_id': u'Orbit Room'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'Salsa Verde', u'cuisine': u'mexican'}
# {u'_id': u"Gulliver's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"The Monkey's Paw"}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u'Cafe Lutz'}
# {u'_id': u"Cheesie's Pub & Grub", u'cuisine': u'sandwich'}
# {u'_id': u'Wishbone Restaurant'}
# {u'_id': u'The Parthenon', u'cuisine': u'greek'}
# {u'_id': u'Greek Islands', u'cuisine': u'greek'}
# {u'_id': u'Kabuki', u'cuisine': u'japanese'}
# {u'_id': u'Burger King', u'cuisine': u'burger'}
# {u'_id': u"Flamingo's", u'cuisine': u'steak_house'}
# {u'_id': u'Cheesecake Factory'}
# {u'_id': u'Kona Grill'}
# {u'_id': u'Arirang', u'cuisine': u'korean'}
# {u'_id': u'Taza', u'cuisine': u'italian'}
# {u'_id': u'The Capital Grille', u'cuisine': u'steak_house'}
# {u'_id': u'HB Home Bistro Chicago', u'cuisine': u'american'}
# {u'_id': u'Lawrence Fish Market', u'cuisine': u'sushi'}
# {u'_id': u'Las Tablas', u'cuisine': u'Brazilian_Steakhouse'}
# {u'_id': u"Dunkin' Donuts/ BR",
#  u'cuisine': u'Donuts,_coffee,_breakfast Sandwiches'}
# {u'_id': u"Frank's Shrimp House",
#  u'cuisine': u'Seafood_to_go - Gulf shrimp, oysters, clams and more'}
# {u'_id': u'Mr. Submarine', u'cuisine': u'Sub,_hot_dogs'}
# {u'_id': u'Hong Kong Restaurant', u'cuisine': u'chinese'}
# {u'_id': u'Noon A Kabab',
#  u'contact': u'(773) 279-8899',
#  u'cuisine': u'Persian'}
# {u'_id': u'McDonalds', u'cuisine': u'burger'}
# {u'_id': u"Godfather's Pizza",
#  u'contact': u'773-878-8600',
#  u'cuisine': u'pizza'}
# {u'_id': u"Perry's Pizza Joynt",
#  u'contact': u'708-562-5334',
#  u'cuisine': u'pizza'}
# {u'_id': u'Fountainhead',
#  u'contact': u'(773) 697-8204',
#  u'cuisine': u'New_American'}
# {u'_id': u'Aroy Thai'}
# {u'_id': u'Roti', u'contact': u'312-332-6013', u'cuisine': u'mediterranean'}
# {u'_id': u'Burger Bar Chicago',
#  u'contact': u'312-255-0055',
#  u'cuisine': u'burger'}
# {u'_id': u'Bluestone Cafe', u'cuisine': u'american'}
# {u'_id': u"Joy's Noodles & Rice", u'cuisine': u'asian'}
# {u'_id': u'Cubs Bar & Grill'}
# {u'_id': u'La Cocina', u'cuisine': u'mexican'}
# {u'_id': u'Staropolska Restaurant'}
# {u'_id': u"Houlihan's", u'cuisine': u'american'}
# {u'_id': u"Jason's Deli", u'cuisine': u'sandwich'}
# {u'_id': u"Moe Joe's"}
# {u'_id': u'El Famous Burrito', u'cuisine': u'mexican'}
# {u'_id': u"Eggy's", u'cuisine': u'diner'}
# {u'_id': u'Peckish Pig'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'Trattoria DOC', u'cuisine': u'italian'}
# {u'_id': u'The Supreme Burrito #1', u'cuisine': u'mexican'}
# {u'_id': u"Nutphree's Cupcakes", u'contact': u'847-754-4320'}
# {u'_id': u"Andy's", u'contact': u'847-864-8009', u'cuisine': u'ice_cream'}
# {u'_id': u"Chicago's Home of Chicken & Waffles", u'cuisine': u'chicken'}
# {u'_id': u"Panino's Pizzeria",
#  u'contact': u'847-475-6200',
#  u'cuisine': u'pizza'}
# {u'_id': u'Bagel Art', u'contact': u'(847) 864-8700', u'cuisine': u'bagel'}
# {u'_id': u"Gigio's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'That Little Mexican Cafe', u'cuisine': u'mexican'}
# {u'_id': u'27 Live'}
# {u'_id': u'Thai Sookdee', u'contact': u'847-866-8012', u'cuisine': u'thai'}
# {u'_id': u'CoZy Noodles & Rice',
#  u'contact': u'847-733-0101',
#  u'cuisine': u'chinese'}
# {u'_id': u'Taco Diablo'}
# {u'_id': u'Pine Yard', u'contact': u'847-475-4940'}
# {u'_id': u'Creperie Saint-Germain', u'cuisine': u'crepes'}
# {u'_id': u'Kansaku', u'cuisine': u'sushi'}
# {u'_id': u"Pete Miller's Steakhouse"}
# {u'_id': u'The Crystal Residence'}
# {u'_id': u'Coldstone Creamery', u'cuisine': u'ice_cream'}
# {u'_id': u'La Macchina Cafe'}
# {u'_id': u'La Cocinita'}
# {u'_id': u'Joy-Yee Szechwan Kitchen', u'cuisine': u'chinese'}
# {u'_id': u'Naf Naf Grill', u'cuisine': u'mediterranean'}
# {u'_id': u'Lao Sze Chuan', u'cuisine': u'thai'}
# {u'_id': u'Soulwich'}
# {u'_id': u'Todoroki', u'cuisine': u'japanese'}
# {u'_id': u'527 Cafe', u'contact': u'847-332-2233'}
# {u'_id': u'Aguas Tortas', u'cuisine': u'mexican'}
# {u'_id': u'Sashimi Sashimi', u'cuisine': u'sushi'}
# {u'_id': u'Tutti Frutti', u'cuisine': u'ice_cream'}
# {u'_id': u'800 Degrees Pizzeria', u'cuisine': u'pizza'}
# {u'_id': u"Chef's Station", u'contact': u'847-570-9821'}
# {u'_id': u'Leonidas', u'contact': u'847-686-0100', u'cuisine': u'chocolate'}
# {u'_id': u"Prairie Joe's"}
# {u'_id': u'Pinto Kitchen'}
# {u'_id': u"Symphony's"}
# {u'_id': u'Coast', u'contact': u'847-328-2221', u'cuisine': u'sushi'}
# {u'_id': u'Pepperpot'}
# {u'_id': u'IDOS Bistro'}
# {u'_id': u"Rollin' To Go", u'cuisine': u'italian'}
# {u'_id': u'Tomate Fresh Kitchen'}
# {u'_id': u"Al's Deli"}
# {u'_id': u'Wings Over...Evanston', u'cuisine': u'wings'}
# {u'_id': u'Olive Meditteranean Grill'}
# {u'_id': u'Mumbai Indian Grill',
#  u'contact': u'847-859-2453',
#  u'cuisine': u'indian'}
# {u'_id': u'The Stained Glass'}
# {u'_id': u'Forever Yogurt', u'cuisine': u'ice_cream'}
# {u'_id': u'Buffalo Wild Wings',
#  u'contact': u'847-570-0333',
#  u'cuisine': u'chicken'}
# {u'_id': u'Prana Caf\xe9'}
# {u'_id': u'Chicken Shack'}
# {u'_id': u"Clarke's"}
# {u'_id': u'Koco Table', u'cuisine': u'korean'}
# {u'_id': u'Hala In',
#  u'contact': u'773-930-3612',
#  u'cuisine': u'Middle_Eastern'}
# {u'_id': u'Layalena Banquets'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u"Chuck's BBQ", u'cuisine': u'Restaurant'}
# {u'_id': u'Kojaks', u'cuisine': u'Hamburger_Joint'}
# {u'_id': u'Durbins', u'cuisine': u'pizza'}
# {u'_id': u'Mabenka', u'cuisine': u'Polish_Food'}
# {u'_id': u'Les Brothers Restaurant', u'cuisine': u'Family_Restaurant'}
# {u'_id': u'Sagils', u'cuisine': u'Polish_Food'}
# {u'_id': u'IHOP', u'cuisine': u'breakfast'}
# {u'_id': u"Nick's BBQ", u'cuisine': u'barbecue'}
# {u'_id': u"Denny's", u'cuisine': u'american'}
# {u'_id': u'The Pit Rib House', u'cuisine': u'Ribs'}
# {u'_id': u"Pepe's"}
# {u'_id': u'Billy Boys'}
# {u'_id': u'Red Lobster'}
# {u'_id': u'Qdoba'}
# {u'_id': u"Jedi's Garden Restaurant"}
# {u'_id': u"Fox's Pub"}
# {u'_id': u"Denny's"}
# {u'_id': u"Hooter's"}
# {u'_id': u'TGI Fridays'}
# {u'_id': u"Jack Desmond's"}
# {u'_id': u"Nick's Pizza"}
# {u'_id': u'El Taqueria'}
# {u'_id': u"Krapil's Great Steak"}
# {u'_id': u"Waldo Cooney's Pizza"}
# {u'_id': u'Pork Shoppe', u'contact': u'773-961-7654'}
# {u'_id': u'Dragon Lady Lounge',
#  u'contact': u'773-267-1970',
#  u'cuisine': u'vegan'}
# {u'_id': u'Corner Bakery'}
# {u'_id': u"Three Floyd's Brewpub"}
# {u'_id': u"Domino's", u'cuisine': u'pizza'}
# {u'_id': u'Unupi Palace', u'cuisine': u'indian'}
# {u'_id': u'Aloha', u'cuisine': u'hawaiian'}
# {u'_id': u'Goose Island Brewery Restaurant'}
# {u'_id': u'ICE Dishes and Drinks'}
# {u'_id': u"Chili's Too", u'cuisine': u'mexican'}
# {u'_id': u'Wolfgang Puck Caf\xe9'}
# {u'_id': u"O'Briens"}
# {u'_id': u"Romano's Macaroni Grill", u'cuisine': u'italian'}
# {u'_id': u'Skyscrapers', u'cuisine': u'sandwich'}
# {u'_id': u'Tortas Frontera', u'cuisine': u'mexican'}
# {u'_id': u'Wolfgang Puck Express'}
# {u'_id': u'Taste of Lebanon', u'cuisine': u'lebanese'}
# {u'_id': u'Club Lucky', u'cuisine': u'italian'}
# {u'_id': u"Lucia's", u'cuisine': u'italian'}
# {u'_id': u'Caff\xe8 Oliva', u'cuisine': u'international'}
# {u'_id': u'The Dock at Montrose Beach', u'cuisine': u'american'}
# {u'_id': u'Wafel', u'contact': u'773-770-4894', u'cuisine': u'breakfast'}
# {u'_id': u'Artists cafe', u'cuisine': u'sandwich'}
# {u'_id': u'East China Inn', u'cuisine': u'chinese'}
# {u'_id': u"Lou Malnati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Bongo Room', u'cuisine': u'breakfast'}
# {u'_id': u'Yang', u'cuisine': u'chinese'}
# {u'_id': u'Yolk', u'cuisine': u'breakfast'}
# {u'_id': u'Mercat a La Plaxa'}
# {u'_id': u'Z&H MarketCafe', u'cuisine': u'sandwich'}
# {u'_id': u'Noodles Etc', u'cuisine': u'asian'}
# {u'_id': u'Little Goat Diner', u'contact': u'312-888-3455'}
# {u'_id': u'Joy Yee Noodle', u'cuisine': u'chinese'}
# {u'_id': u"Tamale's Garibay", u'cuisine': u'mexican'}
# {u'_id': u'Janitzio Burritos Y Tagueria', u'cuisine': u'mexican'}
# {u'_id': u"Chili's Too", u'cuisine': u'mexican'}
# {u'_id': u'Cafe 333'}
# {u'_id': u"Goodwin's"}
# {u'_id': u'Red E'}
# {u'_id': u'Bacci Pizza on Clark', u'cuisine': u'pizza'}
# {u'_id': u'Dragon Express', u'cuisine': u'chinese'}
# {u'_id': u"Fatty's Burgers and More", u'cuisine': u'burger'}
# {u'_id': u'Italian Fiesta Pizzeria', u'cuisine': u'pizza'}
# {u'_id': u'Old Country Buffet', u'cuisine': u'buffet'}
# {u'_id': u"Pat's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Shark's Fish & Chicken", u'cuisine': u'chicken'}
# {u'_id': u'Smoke Signals BBQ', u'cuisine': u'barbecue'}
# {u'_id': u"Zia's Trattoria", u'cuisine': u'italian'}
# {u'_id': u"Jane's Restaurant",
#  u'contact': u'773-862-5263',
#  u'cuisine': u'american'}
# {u'_id': u'Silverado', u'cuisine': u'american'}
# {u'_id': u'Robertos', u'cuisine': u'italian'}
# {u'_id': u"Zaza's Italian Steak House", u'cuisine': u'steak_house'}
# {u'_id': u"Wok n' Fire", u'cuisine': u'japanese'}
# {u'_id': u'Jimmys Pizza Cafe', u'cuisine': u'pizza'}
# {u'_id': u'Lake Bluff Brewing Company'}
# {u'_id': u'Union Pizza', u'cuisine': u'pizza'}
# {u'_id': u'Topo Gigio', u'cuisine': u'italian'}
# {u'_id': u'Fat Rice', u'cuisine': u'asian'}
# {u'_id': u"Amelia's Bar and Grill"}
# {u'_id': u'Takito Grill'}
# {u'_id': u"Emmett's"}
# {u'_id': u'Basil Leaf', u'contact': u'773-935-3388', u'cuisine': u'italian'}
# {u'_id': u"Rocco Ranalli's", u'cuisine': u'pizza'}
# {u'_id': u'Pastoral', u'cuisine': u'french'}
# {u'_id': u'Buona Beef'}
# {u'_id': u'Besa Mi Taco'}
# {u'_id': u'H.B Jones', u'cuisine': u'american'}
# {u'_id': u'La Cabana De Don Luis',
#  u'contact': u'1 (773)-271-5176',
#  u'cuisine': u'mexican'}
# {u'_id': u"Jet's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Taqueria Traspasada', u'cuisine': u'mexican'}
# {u'_id': u'Epic Burger', u'cuisine': u'burger'}
# {u'_id': u'The Great American Bagel', u'cuisine': u'bagel'}
# {u'_id': u"Culver's", u'cuisine': u'burger'}
# {u'_id': u"Frankie's Deli"}
# {u'_id': u'French Quarter'}
# {u'_id': u'Grill Room'}
# {u'_id': u'The Pizza Factory of Barrinton', u'cuisine': u'pizza'}
# {u'_id': u'Meatheads', u'cuisine': u'burger'}
# {u'_id': u'KaleidoScoops', u'cuisine': u'ice_cream'}
# {u'_id': u'Taqueria Moran', u'cuisine': u'mexican'}
# {u'_id': u'BBQ Hut', u'cuisine': u'korean'}
# {u'_id': u"Yu's Mandarin", u'cuisine': u'chinese'}
# {u'_id': u"Eppy's Deli", u'cuisine': u'sandwich'}
# {u'_id': u'La Cocina', u'cuisine': u'mexican'}
# {u'_id': u"Dunkin' Donuts"}
# {u'_id': u'Noodles and Company', u'cuisine': u'noodle'}
# {u'_id': u'Taco Fresco'}
# {u'_id': u"Papa John's", u'cuisine': u'pizza'}
# {u'_id': u"Marcello's", u'cuisine': u'italian'}
# {u'_id': u"L'Patron", u'cuisine': u'mexican'}
# {u'_id': u'Taqueria Traspasada', u'cuisine': u'mexican'}
# {u'_id': u'Noodles & Company'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Potbelly', u'cuisine': u'sandwich'}
# {u'_id': u'Doggie Diner', u'cuisine': u'burger'}
# {u'_id': u'Freshii'}
# {u'_id': u"Wok'n Fire"}
# {u'_id': u'Dolce Bakery and Cafe'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u'Panda Express'}
# {u'_id': u'Potbelly Sandwich Works'}
# {u'_id': u'Red Robin', u'cuisine': u'burger'}
# {u'_id': u'Starbucks Coffee'}
# {u'_id': u'Panera Bread', u'cuisine': u'burger'}
# {u'_id': u'Cochiaros Pizza Resturant', u'cuisine': u'pizza'}
# {u'_id': u"Chili's"}
# {u'_id': u'Weber Grill'}
# {u'_id': u'Peking Chinese Restaurant', u'cuisine': u'chinese'}
# {u'_id': u'V&V Paesano Pizzeria', u'cuisine': u'pizza'}
# {u'_id': u'Endgrain'}
# {u'_id': u'Nile Restaurant'}
# {u'_id': u"Tony's Subs", u'cuisine': u'sandwich'}
# {u'_id': u'Big Delicious Planet'}
# {u'_id': u"Tortorice's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Pepe's Mexican Restaurant", u'cuisine': u'mexican'}
# {u'_id': u"Joe's Hot Dogs", u'cuisine': u'hot_dogs'}
# {u'_id': u'Ace Drive-In', u'cuisine': u'burger'}
# {u'_id': u'III Forks', u'cuisine': u'steak_house'}
# {u'_id': u'Vapiano'}
# {u'_id': u'LYFE Kitchen'}
# {u'_id': u'Wing Stop'}
# {u'_id': u"Petterino's"}
# {u'_id': u'Brazzaz'}
# {u'_id': u'NYC Bagel Deli', u'cuisine': u'sandwich'}
# {u'_id': u'Square Bar', u'cuisine': u'american'}
# {u'_id': u'Ho Luck', u'cuisine': u'chinese'}
# {u'_id': u'On the Border', u'cuisine': u'mexican'}
# {u'_id': u'Potbelly'}
# {u'_id': u'Sandpiper Restaurant'}
# {u'_id': u'Edelweiss', u'cuisine': u'german, american'}
# {u'_id': u'Lincoln Park Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Joe's", u'cuisine': u'steak, seafood'}
# {u'_id': u"Big Sammy's Hot Dogs"}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'McGonigals Irish Pub'}
# {u'_id': u'Original Tracks', u'cuisine': u'hot_dog'}
# {u'_id': u'Masa Azul',
#  u'contact': u'(773) 687-0300',
#  u'cuisine': u'Tequila_Bar'}
# {u'_id': u'Yusho', u'contact': u'(773) 904-8558', u'cuisine': u'Yakitori'}
# {u'_id': u'Buona'}
# {u'_id': u"Big Guy's Sausage"}
# {u'_id': u"Culver's"}
# {u'_id': u'Autre Monde Cafe'}
# {u'_id': u'Golden Steer Steakhouse'}
# {u'_id': u"Sawa's Old Warsaw"}
# {u'_id': u"D'Agostino's Pizzeria Wheeling"}
# {u'_id': u'Quartino', u'cuisine': u'Tapas'}
# {u'_id': u'Cos\xec', u'contact': u'+1 312 368 4400'}
# {u'_id': u'Taco Joint', u'cuisine': u'Taqueria/Cantina'}
# {u'_id': u'Rustic House'}
# {u'_id': u'Pasta Palazzo', u'cuisine': u'italian'}
# {u'_id': u'Coppervine'}
# {u'_id': u'Brothers Beef', u'cuisine': u'fast_food'}
# {u'_id': u"Maravilla's", u'cuisine': u'mexican'}
# {u'_id': u'Thai Garden', u'cuisine': u'thai'}
# {u'_id': u'China Buffett', u'cuisine': u'chinese'}
# {u'_id': u'Bar Louie'}
# {u'_id': u'Crave Cafe and Lounge', u'cuisine': u'Comfort_Food'}
# {u'_id': u'Pho Xe Tang',
#  u'contact': u'(773) 878-2253',
#  u'cuisine': u'vietnamese'}
# {u'_id': u'Pho Saigon', u'cuisine': u'vietnamese'}
# {u'_id': u'The Berghoff Caf\xe9', u'cuisine': u'sandwich'}
# {u'_id': u'Thai Urban Kitchen', u'cuisine': u'thai'}
# {u'_id': u'Cafe Laguardia', u'cuisine': u'cuban'}
# {u'_id': u'Devon', u'cuisine': u'seafood, steak'}
# {u'_id': u'Trattoria Trullo', u'cuisine': u'italian'}
# {u'_id': u'Barba Yianni', u'cuisine': u'greek'}
# {u'_id': u'The Original Pancake House'}
# {u'_id': u'M2 Cafe', u'cuisine': u'coffee_shop'}
# {u'_id': u'Taco Burrito King', u'cuisine': u'mexican'}
# {u'_id': u'Chinese Yum Yum', u'cuisine': u'asian'}
# {u'_id': u'Golden Corral', u'cuisine': u'buffett'}
# {u'_id': u'Oak Park Kitchen and Bar'}
# {u'_id': u'The Khyber Pass', u'cuisine': u'indian'}
# {u'_id': u'Daddy O\u2019s Diner of Itasca', u'cuisine': u'burger'}
# {u'_id': u'Tree Guys Pizza Pub', u'cuisine': u'pizza'}
# {u'_id': u'Casale Pizza', u'cuisine': u'pizza'}
# {u'_id': u'Cucina Casale'}
# {u'_id': u'Buenos Dias Burritos', u'cuisine': u'mexican'}
# {u'_id': u'Bread & Butter Restaurant'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u'California Pizza Kitchen', u'cuisine': u'pizza'}
# {u'_id': u'Cool Mirchi Indian Restaurant', u'cuisine': u'indian'}
# {u'_id': u'El Barrio', u'cuisine': u'mexican'}
# {u'_id': u'Krispy Kreme Doughnuts Factory Cafe',
#  u'contact': u'1 (847) 472-9500'}
# {u'_id': u"Jet's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Home Run Pizza'}
# {u'_id': u'Golden Wok II', u'cuisine': u'chinese'}
# {u'_id': u'Indian Bistro', u'cuisine': u'indian'}
# {u'_id': u'Milwalky Trace', u'contact': u'8475307172', u'cuisine': u'american'}
# {u'_id': u'Chicago Pizza and Catering', u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Tomato's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Papa Saverio's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Taylor Street Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Papa Saverio's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Rosati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Cassava', u'cuisine': u'South_American_cassava bread & empanadas'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u'De Allende', u'cuisine': u'italian'}
# {u'_id': u'Burger King', u'cuisine': u'burger'}
# {u'_id': u'The Chicago Diner'}
# {u'_id': u'Uncommon Ground'}
# {u'_id': u"Houlihan's", u'cuisine': u'Bar_and_Grill'}
# {u'_id': u"Tom Kelley's Chop House & Pub"}
# {u'_id': u'Bombay Grill', u'cuisine': u'indian'}
# {u'_id': u'Main Street Greek Kitchen', u'cuisine': u'greek'}
# {u'_id': u'Flying Saucer'}
# {u'_id': u'Dos Urban Cantina', u'cuisine': u'mexican'}
# {u'_id': u'Chipotle', u'cuisine': u'mexican'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u'Entree Kitchen', u'cuisine': u'italian'}
# {u'_id': u"Jin's China", u'cuisine': u'chinese'}
# {u'_id': u"Addante's Pizza & Catering", u'cuisine': u'pizza'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u'Potbelly'}
# {u'_id': u"Rosati's Pizza"}
# {u'_id': u"Ken's", u'cuisine': u'breakfast'}
# {u'_id': u'panda express', u'cuisine': u'chinese'}
# {u'_id': u'Dairy Queen'}
# {u'_id': u'Akai Hana', u'contact': u'847-251-0384', u'cuisine': u'japanese'}
# {u'_id': u"Lou Malnati's Pizzeria",
#  u'contact': u'(847) 256-5780',
#  u'cuisine': u'pizza'}
# {u'_id': u'TGI Fridays', u'cuisine': u'american'}
# {u'_id': u'The Lantern', u'cuisine': u'american'}
# {u'_id': u'Koya', u'cuisine': u'japanese'}
# {u'_id': u'Long Grove Tavern'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Oswego/Douglas Rd'}
# {u'_id': u'Sweetwater'}
# {u'_id': u"Jimmy John's1"}
# {u'_id': u'Corner Bakery'}
# {u'_id': u"Hoyt's"}
# {u'_id': u"McCormick & Schmick's"}
# {u'_id': u'South Water Kitchen'}
# {u'_id': u'Emerald Loop'}
# {u'_id': u'Billy Goat Tavern', u'cuisine': u'burger'}
# {u'_id': u'Gold Coast Dogs'}
# {u'_id': u'Subway'}
# {u'_id': u"Mrs Field's1"}
# {u'_id': u"America's Dog"}
# {u'_id': u'Chipolte', u'cuisine': u'mexican'}
# {u'_id': u'Subway'}
# {u'_id': u'Atwood Cafe'}
# {u'_id': u'Wow Bao'}
# {u'_id': u'Protein Bar'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Chicago Curry House', u'cuisine': u'indian'}
# {u'_id': u'Pho Lily'}
# {u'_id': u'Japonais by Morimoto', u'cuisine': u'japanese'}
# {u'_id': u'Motel Bar', u'cuisine': u'Bar_Food'}
# {u'_id': u"Snarf's", u'cuisine': u'sandwich'}
# {u'_id': u'Goddess & the Grocer', u'cuisine': u'sandwich'}
# {u'_id': u'Depot Nuevo', u'cuisine': u'mexican'}
# {u'_id': u"Rub's Backcountry Smokehouse",
#  u'cuisine': u'BBQ,_Smokehouse,_Pulled Pork, Brisket, Homemade Root Beer'}
# {u'_id': u'Taco Buritto King', u'cuisine': u'mexican'}
# {u'_id': u'Mezza Mediterranean Grill', u'cuisine': u'mediterranean'}
# {u'_id': u'Yolk', u'cuisine': u'breakfast'}
# {u'_id': u"McDonald's", u'cuisine': u'burger'}
# {u'_id': u'The General'}
# {u'_id': u'McDonalds', u'cuisine': u'burger'}
# {u'_id': u'Centro'}
# {u'_id': u'Reno', u'cuisine': u'italian'}
# {u'_id': u"Egg'lectic Cafe", u'contact': u'630-260-9001'}
# {u'_id': u"Dino's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Fahlstrom's Fresh Fish Market", u'contact': u'+1 773 281 6000'}
# {u'_id': u"Leona's Restaurant - Beverly", u'cuisine': u'pizza'}
# {u'_id': u"Waldo Cooney's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Brick's", u'cuisine': u'italian'}
# {u'_id': u'Sakura', u'cuisine': u'japanese'}
# {u'_id': u"Pequod's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Pauly's Pizza-Ria", u'cuisine': u'pizza'}
# {u'_id': u"Jimmy Green's"}
# {u'_id': u'Pret A Manger'}
# {u'_id': u'Qdoba', u'cuisine': u'mexican'}
# {u'_id': u'Qdoba Grill'}
# {u'_id': u'Villa Bleu'}
# {u'_id': u"Beggar's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'BurgerFi', u'contact': u'+1 (847) 376-8014', u'cuisine': u'burger'}
# {u'_id': u'The Milk Pail'}
# {u'_id': u"Noodle's & Co."}
# {u'_id': u'Good Foods Vegan/Vegetarian Deli', u'cuisine': u'vegetarian'}
# {u'_id': u'L&G Restaurant', u'cuisine': u'american'}
# {u'_id': u'The Snail', u'cuisine': u'thai'}
# {u'_id': u'Cafe Babareeba',
#  u'contact': u'(773) 935-5000',
#  u'cuisine': u'Tapas'}
# {u'_id': u'India House', u'cuisine': u'indian'}
# {u'_id': u'Bakers Square', u'cuisine': u'american'}
# {u'_id': u"Garcia's", u'cuisine': u'mexican'}
# {u'_id': u"Lady Gregory's"}
# {u'_id': u'Delux'}
# {u'_id': u'Pita Inn'}
# {u'_id': u"Culver's"}
# {u'_id': u"Popeye's"}
# {u'_id': u"Portillo's Barnelli's"}
# {u'_id': u'Chipotle', u'cuisine': u'mexican'}
# {u'_id': u"Jimmy John's", u'cuisine': u'sandwich'}
# {u'_id': u'Hong Kong Chop Suey', u'cuisine': u'chinese'}
# {u'_id': u"Stanley's Kitchen and Tap"}
# {u'_id': u'Something North', u'cuisine': u'Ice_cream'}
# {u'_id': u'Cedar Lake Kitchen'}
# {u'_id': u"Domino's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Lou Malnati's Pizzeria"}
# {u'_id': u'Leader Bar Drafthouse', u'cuisine': u'burger'}
# {u'_id': u'Pitchfork Food & Saloon', u'cuisine': u'barbecue'}
# {u'_id': u'Sticky Rice', u'cuisine': u'thai'}
# {u'_id': u"Dapper's East Family Restaurant"}
# {u'_id': u'Mi Cuidad', u'cuisine': u'ecuadorian'}
# {u'_id': u'Dharma Garden', u'cuisine': u'thai'}
# {u'_id': u'The Famous Taco Burrito', u'cuisine': u'mexican'}
# {u'_id': u"Lo's China Kitchen", u'cuisine': u'chinese'}
# {u'_id': u"Potbelly's", u'cuisine': u'sandwich'}
# {u'_id': u'Acre'}
# {u'_id': u'Polygon Cafe', u'cuisine': u'thai'}
# {u'_id': u'Svea', u'cuisine': u'swedish'}
# {u'_id': u'Einstein Bros Bagels', u'cuisine': u'bagel'}
# {u'_id': u"Ranalli's", u'cuisine': u'pizza'}
# {u'_id': u'm. henry', u'cuisine': u'brunch'}
# {u'_id': u'Rookies'}
# {u'_id': u'D & J Bistro', u'cuisine': u'french'}
# {u'_id': u'Dublins Bar and Grill'}
# {u'_id': u'Tweet'}
# {u'_id': u'Black Bull Tapas'}
# {u'_id': u'The Bongo Room'}
# {u'_id': u"Lucky's Sandwich Co.", u'cuisine': u'sandwich'}
# {u'_id': u'Antique taco', u'cuisine': u'mexican'}
# {u'_id': u'IHOP'}
# {u'_id': u'Coco Pazzo'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Buffalo Wild Wings'}
# {u'_id': u'Red Robin'}
# {u'_id': u'Dastorkon', u'cuisine': u'kyrgyz'}
# {u'_id': u'Pal Joeys', u'contact': u'1 630 593 6600', u'cuisine': u'italian'}
# {u'_id': u'Egg Harbor Cafe'}
# {u'_id': u"Lou Malnati's Pizzeria"}
# {u'_id': u'House of Bing', u'cuisine': u'chinese'}
# {u'_id': u'Tacos El Norte',
#  u'contact': u'(847) 458-4777',
#  u'cuisine': u'mexican'}
# {u'_id': u'Chipotle', u'cuisine': u'mexican'}
# {u'_id': u'Naf Naf Grill'}
# {u'_id': u"Lou Malnati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Buffalo Wings & Rings', u'cuisine': u'american'}
# {u'_id': u'Fiesta Burrito', u'cuisine': u'mexican'}
# {u'_id': u'Old World Pizza'}
# {u'_id': u'Port Edward', u'contact': u'(847) 658-5441'}
# {u'_id': u'Subway'}
# {u'_id': u"Fat Ricky's", u'contact': u'+1 815 2932900'}
# {u'_id': u'Tacos Villa', u'cuisine': u'mexican'}
# {u'_id': u'Gnarly Knots', u'cuisine': u'american'}
# {u'_id': u"Ruby's Burritos",
#  u'contact': u'+1 815 3729146',
#  u'cuisine': u'mexican'}
# {u'_id': u"Ruby's Pancake House", u'contact': u'+1 815 3729185'}
# {u'_id': u'Panda Express',
#  u'contact': u'+1 630 7831845',
#  u'cuisine': u'chinese'}
# {u'_id': u'Kintaro', u'cuisine': u'japanese'}
# {u'_id': u"Nancy's Pizza", u'contact': u'+1 630 2430033', u'cuisine': u'pizza'}
# {u'_id': u'Promontory Restaurant', u'cuisine': u'american'}
# {u'_id': u"Betty's Bistro"}
# {u'_id': u'Tap House Grill Lemont', u'contact': u'+1 630 2575992'}
# {u'_id': u'IHOP', u'contact': u'+1 630 9729682'}
# {u'_id': u'China Cook', u'cuisine': u'chinese'}
# {u'_id': u"Mike's Place"}
# {u'_id': u"Francesca's", u'contact': u'+1 630 7396300'}
# {u'_id': u'Masada'}
# {u'_id': u'Cafe Cubano', u'contact': u'(708) 456-6100', u'cuisine': u'cuban'}
# {u'_id': u'Inari Sushi', u'cuisine': u'sushi'}
# {u'_id': u'Massa', u'cuisine': u'italian'}
# {u'_id': u'New Star', u'cuisine': u'chinese'}
# {u'_id': u'Spiggiea', u'contact': u'(708) 583-0002', u'cuisine': u'italian'}
# {u'_id': u'Trattoria Peppino'}
# {u'_id': u'Dogfather', u'cuisine': u'burger'}
# {u'_id': u'Honky Tonk BBQ'}
# {u'_id': u"Simone's"}
# {u'_id': u'Taqueria El Milagro', u'cuisine': u'mexican'}
# {u'_id': u'Red Apple Pancake House', u'cuisine': u'breakfast'}
# {u'_id': u'Red Apple Pancake House', u'cuisine': u'breakfast'}
# {u'_id': u'Geek Bar Beta', u'cuisine': u'Awesome_Sauce'}
# {u'_id': u'Bella Vista Mexican Restaurant', u'cuisine': u'mexican'}
# {u'_id': u'Sofi Restaurant'}
# {u'_id': u'The Harding Tavern', u'cuisine': u'burger'}
# {u'_id': u'Armitage Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Ming's Chop Suey", u'cuisine': u'chinese'}
# {u'_id': u'Hoagy House', u'cuisine': u'sandwich'}
# {u'_id': u'Kennedy Fish and Chicken', u'cuisine': u'chicken'}
# {u'_id': u"Surf's Up", u'cuisine': u'seafood'}
# {u'_id': u"Shark's Fish and Chicken", u'cuisine': u'fish'}
# {u'_id': u"DeMarco's Restaurant", u'cuisine': u'italian'}
# {u'_id': u'Golden Nugget Pancake House', u'cuisine': u'Diner_american'}
# {u'_id': u"Dunkin' Donuts"}
# {u'_id': u'Italian Fiesta', u'cuisine': u'pizza'}
# {u'_id': u'Islamorada Fish Company', u'contact': u'+1 630 2962600'}
# {u'_id': u'Goroma', u'contact': u'+1 630 7392660', u'cuisine': u'italian'}
# {u'_id': u'Mago Grill & Cantina', u'contact': u'+1 630 7832222'}
# {u'_id': u'Panera Bread', u'cuisine': u'cafe'}
# {u'_id': u'Boston Market'}
# {u'_id': u'Noodles & Company'}
# {u'_id': u"TGI Friday's"}
# {u'_id': u'Prasino',
#  u'contact': u'(708) 469-7058',
#  u'cuisine': u'Contemporary_American'}
# {u'_id': u'Nicksons', u'contact': u'708-354-4995', u'cuisine': u'regional'}
# {u'_id': u"Al's Charhouse", u'contact': u'(708)3546255'}
# {u'_id': u'Casa Margarita',
#  u'contact': u'708-354-CASA',
#  u'cuisine': u'mexican'}
# {u'_id': u'Q BBQ', u'contact': u'708.482.8700'}
# {u'_id': u'Bella Bacinos', u'contact': u'(708)3528882', u'cuisine': u'italian'}
# {u'_id': u'Luccas', u'contact': u'708-354-9990', u'cuisine': u'italian'}
# {u'_id': u'Jerusalem Cafe'}
# {u'_id': u'Subway'}
# {u'_id': u'The Purple Pig'}
# {u'_id': u'Grand Lux Cafe'}
# {u'_id': u"Ted's Montana Grill", u'contact': u'+1 630 7832493'}
# {u'_id': u"BD's Mongolian Grill", u'contact': u'+1 630 9720450'}
# {u'_id': u'Left Bank'}
# {u'_id': u'Panera Bread', u'cuisine': u'sandwich'}
# {u'_id': u'La Colonial'}
# {u'_id': u'Lemont House Restaurant', u'contact': u'+1 630 2573080'}
# {u'_id': u"Benedict's"}
# {u'_id': u"Chef's Burger Bistro", u'cuisine': u'burger'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Three Tarts Bakery and Cafe'}
# {u'_id': u"Stormy's"}
# {u'_id': u'The Happ Inn'}
# {u'_id': u'Zoba Noodle Bar',
#  u'contact': u'+1 847 328 9622',
#  u'cuisine': u'asian'}
# {u'_id': u'Pret A Manger'}
# {u'_id': u'Protein Bar'}
# {u'_id': u'Phoenix', u'cuisine': u'chinese'}
# {u'_id': u'High Five Ramen', u'cuisine': u'japanese'}
# {u'_id': u'Green Street Smoked Meats', u'cuisine': u'american'}
# {u'_id': u'Over Easy Cafe', u'cuisine': u'american'}
# {u'_id': u'Townhouse Restaurant & Wine Bar'}
# {u'_id': u'Famous Dave'}
# {u'_id': u"Giordano's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Jimmy's Charhouse", u'cuisine': u'regional'}
# {u'_id': u'Montarra', u'contact': u'847-458-0505'}
# {u'_id': u'Golden Corral Buffet & Grill', u'contact': u'847-658-8899'}
# {u'_id': u'Dominos Pizza', u'cuisine': u'pizza'}
# {u'_id': u'Chicken Shop', u'cuisine': u'american'}
# {u'_id': u'Incontro A Tavola',
#  u'contact': u'(847) 836-1700',
#  u'cuisine': u'italian'}
# {u'_id': u"WOK'n FIRE", u'contact': u'(847) 428-7192', u'cuisine': u'japanese'}
# {u'_id': u'Gourmet House Corporation',
#  u'contact': u'(847) 458-7883',
#  u'cuisine': u'chinese'}
# {u'_id': u'Chipotle Mexican Grill'}
# {u'_id': u"Moretti's Ristorante & Pizzeria", u'contact': u'(847) 854-7220'}
# {u'_id': u'North Of The Border', u'cuisine': u'mexican'}
# {u'_id': u'Quiznos', u'cuisine': u'sandwich'}
# {u'_id': u'Jersey Mikes', u'cuisine': u'sandwich'}
# {u'_id': u'Wrigley BBQ', u'cuisine': u'barbecue'}
# {u'_id': u"Chili's"}
# {u'_id': u'Thaiday Street Cafe', u'cuisine': u'thai'}
# {u'_id': u'Citrus Diner', u'cuisine': u'american'}
# {u'_id': u'Pizza Capri', u'cuisine': u'deep_dish_pizza_and_general_Italian'}
# {u'_id': u'Boka', u'cuisine': u'american'}
# {u'_id': u'Vinci', u'cuisine': u'italian'}
# {u'_id': u'Alinea'}
# {u'_id': u'Circle Sushi & Grill'}
# {u'_id': u'Dawali Mediterranean Kitchen', u'cuisine': u'mediterranean'}
# {u'_id': u'Balena', u'cuisine': u'italian'}
# {u'_id': u'Olive Mediterranean Grill', u'cuisine': u'mediterranean'}
# {u'_id': u"Frank's & Dawgs", u'cuisine': u'hot_dogs'}
# {u'_id': u"Amato's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Jaimito's Burritos", u'cuisine': u'mexican'}
# {u'_id': u'El Nuevo Mexicano',
#  u'contact': u'773 528 2131',
#  u'cuisine': u'mexican'}
# {u'_id': u"Novi's Beef",
#  u'contact': u'(708) 749-0895',
#  u'cuisine': u'Italian_Beef,_Burgers,_Hotdogs,_Tacos'}
# {u'_id': u'Indian Garden', u'cuisine': u'indian'}
# {u'_id': u"Choi's Chinese", u'cuisine': u'chinese'}
# {u'_id': u'Azucar', u'cuisine': u'tapas'}
# {u'_id': u'Parts & Labor', u'cuisine': u'burger'}
# {u'_id': u'Bahn Mi Baget', u'cuisine': u'sandwich'}
# {u'_id': u'Thank You.', u'cuisine': u'chinese'}
# {u'_id': u'Jam'}
# {u'_id': u'Trike', u'cuisine': u'thai'}
# {u'_id': u'Osteria Langhe', u'cuisine': u'italian'}
# {u'_id': u'Sink|Swim'}
# {u'_id': u"Juanita's Puerto Rican Cuisine", u'cuisine': u'puerto_rican'}
# {u'_id': u'Dena Kitchen', u'cuisine': u'thai'}
# {u'_id': u'Tacos Tequilas', u'cuisine': u'mexican'}
# {u'_id': u'The Spice', u'cuisine': u'thai'}
# {u'_id': u"Giordano's", u'cuisine': u'pizza'}
# {u'_id': u'Red Apple Buffet', u'cuisine': u'polish'}
# {u'_id': u'Buona Terra', u'cuisine': u'italian'}
# {u'_id': u'Anong', u'cuisine': u'thai'}
# {u'_id': u'Gosu', u'cuisine': u'korean'}
# {u'_id': u"Letizia's Fiore", u'cuisine': u'italian'}
# {u'_id': u"Hachi's Kitchen", u'cuisine': u'sushi'}
# {u'_id': u'La Oaxaque\xf1a', u'cuisine': u'mexican'}
# {u'_id': u'Wasabi', u'cuisine': u'sushi'}
# {u'_id': u'El Guanaco', u'cuisine': u'salvadoran'}
# {u'_id': u"Dove's Luncheonette"}
# {u'_id': u'Silom 12', u'cuisine': u'thai'}
# {u'_id': u'El Nuevo Borinquen', u'cuisine': u'puerto_rican'}
# {u'_id': u'Furious Spoon', u'cuisine': u'japanese'}
# {u'_id': u"Francesca's Forno", u'cuisine': u'italian'}
# {u'_id': u'China Fast Wok', u'cuisine': u'chinese'}
# {u'_id': u'El Gallo Bravo #2', u'cuisine': u'mexican'}
# {u'_id': u'El Rinconcito Cubano', u'cuisine': u'cuban'}
# {u'_id': u'El \xd1and\xfa', u'cuisine': u'argentinian'}
# {u'_id': u'4 Suyos', u'cuisine': u'peruvian'}
# {u'_id': u'La Cocina Boricua', u'cuisine': u'puerto_rican'}
# {u'_id': u'Blue Willow', u'cuisine': u'chinese'}
# {u'_id': u'Fullerton Restaurant'}
# {u'_id': u'Son of a Butcher'}
# {u'_id': u'La Bomba', u'cuisine': u'puerto_rican'}
# {u'_id': u'Tacos Garcias', u'cuisine': u'mexican'}
# {u'_id': u'Ground Control', u'cuisine': u'vegetarian'}
# {u'_id': u'Friendship Chinese', u'cuisine': u'chinese'}
# {u'_id': u'Bite Cafe'}
# {u'_id': u'Boeufhaus'}
# {u'_id': u'Feed', u'cuisine': u'chicken'}
# {u'_id': u'Enoteca Roma', u'cuisine': u'italian'}
# {u'_id': u'Folklore', u'cuisine': u'argentinian'}
# {u'_id': u"Pizano's", u'cuisine': u'pizza'}
# {u'_id': u'Thai Village', u'cuisine': u'thai'}
# {u'_id': u'Mirai', u'cuisine': u'sushi'}
# {u'_id': u'Picante', u'cuisine': u'mexican'}
# {u'_id': u"Jerry's", u'cuisine': u'sandwich'}
# {u'_id': u'Bob San', u'cuisine': u'sushi'}
# {u'_id': u'Carriage House', u'cuisine': u'regional'}
# {u'_id': u'Authentaco', u'cuisine': u'mexican'}
# {u'_id': u'La Pasadita', u'cuisine': u'mexican'}
# {u'_id': u'Restaurant Veneno de Nayarit', u'cuisine': u'mexican'}
# {u'_id': u'Green Zebra', u'cuisine': u'vegetarian'}
# {u'_id': u'Manee Thai', u'cuisine': u'thai'}
# {u'_id': u"Mr. Brown's Lounge", u'cuisine': u'jamaican'}
# {u'_id': u'Trenchermen', u'cuisine': u'american'}
# {u'_id': u'Chop Shop'}
# {u'_id': u'Handlebar', u'cuisine': u'vegetarian'}
# {u'_id': u'Thai Lagoon', u'cuisine': u'thai'}
# {u'_id': u'Rangoli', u'contact': u'773-697-7114', u'cuisine': u'indian'}
# {u'_id': u'Las Asadas', u'cuisine': u'mexican'}
# {u'_id': u"John's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Quesadilla la Reyna del Sur', u'cuisine': u'mexican'}
# {u'_id': u'Birrieria Estilo Jalisco', u'cuisine': u'mexican'}
# {u'_id': u'Paladar Restaurant & Rum Bar', u'cuisine': u'cuban'}
# {u'_id': u'Blaze Pizza', u'cuisine': u'pizza'}
# {u'_id': u'Epic Burger', u'cuisine': u'burger'}
# {u'_id': u'Dao', u'cuisine': u'thai'}
# {u'_id': u'Emilios Tapas', u'cuisine': u'spanish'}
# {u'_id': u'Tre Soldi', u'cuisine': u'italian'}
# {u'_id': u'Gyu-Kaku', u'cuisine': u'japanese'}
# {u'_id': u'Next'}
# {u'_id': u'Local Root'}
# {u'_id': u'Flour & Stone', u'cuisine': u'pizza'}
# {u'_id': u'Xoco'}
# {u'_id': u'Topolobampo'}
# {u'_id': u'Frontera Grill'}
# {u'_id': u'La Scarola', u'cuisine': u'italian'}
# {u'_id': u"Santullo's Eatery", u'cuisine': u'pizza'}
# {u'_id': u'En Hakkore', u'cuisine': u'korean'}
# {u'_id': u"Sarpino's", u'cuisine': u'pizza'}
# {u'_id': u'Izakaya Mita', u'cuisine': u'japanese'}
# {u'_id': u'Presidio'}
# {u'_id': u'Sticky Rice Chiang Mai',
#  u'contact': u'(312) 818-1810',
#  u'cuisine': u'thai'}
# {u'_id': u"Dante's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u'Zoku Sushi', u'cuisine': u'sushi'}
# {u'_id': u'La Encantada', u'cuisine': u'mexican'}
# {u'_id': u'Q-Tine'}
# {u'_id': u'Lao Sze Chuan', u'cuisine': u'chinese'}
# {u'_id': u'Lao Sze Chuan', u'cuisine': u'chinese'}
# {u'_id': u'Tierra Caliente', u'cuisine': u'mexican'}
# {u'_id': u'Ruxbin',
#  u'contact': u'(312) 624\u20138509',
#  u'cuisine': u'american'}
# {u'_id': u"Charlie's Restaurant"}
# {u'_id': u'Del Seoul', u'contact': u'+1-773-248-4BBQ', u'cuisine': u'korean'}
# {u'_id': u"Kuma's Too", u'contact': u'+1-773-472-2666', u'cuisine': u'burger'}
# {u'_id': u"Raymond's Tacos", u'cuisine': u'mexican'}
# {u'_id': u'Vito & Angelo Pizzeria', u'cuisine': u'pizza'}
# {u'_id': u'Hoanh Long', u'cuisine': u'vietnamese'}
# ...
# {u'_id': u'Jin 28'}
# {u'_id': u'La Sorella Di Francesca'}
# {u'_id': u'Noodles & Company'}
# {u'_id': u"Nando's Peri-Peri"}
# {u'_id': u'Cantina Laredo'}
# {u'_id': u"Parkers'"}
# {u'_id': u'31st Street Beach House'}
# {u'_id': u"Church's Chicken"}
# {u'_id': u'Pita Inn', u'cuisine': u'middle_eastern'}
# {u'_id': u'Kanela'}
# {u'_id': u"Denny's", u'cuisine': u'american'}
# {u'_id': u'Chateau Ritz'}
# {u'_id': u"Moon's", u'cuisine': u'sandwich'}
# {u'_id': u'New China Restaurant', u'cuisine': u'chinese'}
# {u'_id': u"Guerrero's Tacos and Pizza", u'cuisine': u'pizza'}
# {u'_id': u'La Bruquena'}
# {u'_id': u'Taco el Jalisciense'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'Irazu', u'cuisine': u'costa_rican'}
# {u'_id': u"Arturo's Tacos", u'cuisine': u'mexican'}
# {u'_id': u"Lazo's", u'cuisine': u'mexican'}
# {u'_id': u'The Art of Chicken', u'cuisine': u'chicken'}
# {u'_id': u'Red Hot Ranch', u'cuisine': u'Hot_dog,Polish sausage,Fried shrimp'}
# {u'_id': u'Taqueria Los Comales #11', u'cuisine': u'mexican'}
# {u'_id': u'Cafeteria Marianao', u'cuisine': u'cuban'}
# {u'_id': u'Cozy Corner Diner'}
# {u'_id': u'Don Chema', u'cuisine': u'mexican'}
# {u'_id': u'90 Miles Cuban Cafe', u'cuisine': u'Hispanic,_Cuban'}
# {u'_id': u'Table, Donkey & Stick'}
# {u'_id': u"Parson's Chicken & Fish", u'cuisine': u'american'}
# {u'_id': u"Fat Willy's", u'cuisine': u'barbecue'}
# {u'_id': u"Marcello's Father & Son Restaurant", u'cuisine': u'italian'}
# {u'_id': u'Golden Nugget'}
# {u'_id': u'IHOP', u'cuisine': u'diner'}
# {u'_id': u'The Radler', u'cuisine': u'german'}
# {u'_id': u'\xf1', u'contact': u'+17738669898', u'cuisine': u'argentinian'}
# {u'_id': u'90 Miles', u'cuisine': u'Cuban'}
# {u'_id': u'Honey Butter Fried Chicken'}
# {u'_id': u'Viceroy of India', u'cuisine': u'indian'}
# {u'_id': u'The Main Pizza / Chalavi', u'cuisine': u'pizza'}
# {u'_id': u'Foxes Pub', u'cuisine': u'pizza'}
# {u'_id': u'Pompeii'}
# {u'_id': u'El Taco Veloz', u'cuisine': u'mexican'}
# {u'_id': u'Breakfast House', u'cuisine': u'breakfast'}
# {u'_id': u'El Barco Mariscos', u'cuisine': u'mexican'}
# {u'_id': u'The Frontier'}
# {u'_id': u'Podhalanka', u'cuisine': u'polish'}
# {u'_id': u'Pizza Metro', u'contact': u'773-278-1753', u'cuisine': u'pizza'}
# {u'_id': u'Tocco'}
# {u'_id': u"Columbus' Curry"}
# {u'_id': u"Harold's Chicken #36", u'cuisine': u'chicken'}
# {u'_id': u'Pot Pan', u'cuisine': u'thai'}
# {u'_id': u'Mott St.'}
# {u'_id': u'Smoke Daddy', u'cuisine': u'barbecue'}
# {u'_id': u'Cumin',
#  u'contact': u'773-342-1414',
#  u'cuisine': u'Nepalese_and_Indian_cuisine'}
# {u'_id': u'Umami Burger', u'cuisine': u'burger'}
# {u'_id': u'Native Foods Cafe'}
# {u'_id': u'Big Star', u'cuisine': u'mexican'}
# {u'_id': u'Papajin', u'cuisine': u'sushi'}
# {u'_id': u'Hollywood Grill'}
# {u'_id': u'Small Cheval', u'cuisine': u'burger'}
# {u'_id': u"Mindy's Hot Chocolate"}
# {u'_id': u'The Southern'}
# {u'_id': u"Miko's Italian Ice", u'cuisine': u'ice_cream'}
# {u'_id': u"Lillie's Q", u'contact': u'773-772-5500', u'cuisine': u'barbecue'}
# {u'_id': u'Boston Market'}
# {u'_id': u'Knife & Tine'}
# {u'_id': u'Via Carducci'}
# {u'_id': u'The Squared Circle'}
# {u'_id': u'Flo', u'cuisine': u'latin'}
# {u'_id': u'S&G Restaurant', u'cuisine': u'american'}
# {u'_id': u"Byron's Hotdogs", u'cuisine': u'burger'}
# {u'_id': u'Golden Nugget Pancake House', u'cuisine': u'american'}
# {u'_id': u"Andie's", u'cuisine': u'mediterranean'}
# {u'_id': u"Reza's", u'cuisine': u'mediterranean'}
# {u'_id': u'Pork Shoppe', u'cuisine': u'barbecue'}
# {u'_id': u'Uncommon Ground'}
# {u'_id': u"Leona's"}
# {u'_id': u"Buffalo Joe's"}
# {u'_id': u'BJ"s Market & Bakery', u'cuisine': u'Soul Food'}
# {u'_id': u'The Duck Inn'}
# {u'_id': u'Pegasus', u'cuisine': u'greek'}
# {u'_id': u'Coalfire', u'contact': u'312.226.2625', u'cuisine': u'pizza'}
# {u'_id': u'Santorini', u'cuisine': u'greek'}
# {u'_id': u'Athena', u'cuisine': u'greek'}
# {u'_id': u"Mart Anthony's"}
# {u'_id': u'Carnivale'}
# {u'_id': u'Dragonfly', u'contact': u'312-455-1400', u'cuisine': u'chinese'}
# {u'_id': u'Silver Palm'}
# {u'_id': u'The Butcher & the Burger', u'cuisine': u'burger'}
# {u'_id': u"Tarantino's"}
# {u'_id': u'Chipotle Mexican Grill', u'cuisine': u'mexican'}
# {u'_id': u'Simply it', u'cuisine': u'vietnamese'}
# {u'_id': u"Uncle Julio's", u'cuisine': u'mexican'}
# {u'_id': u'Sono Wood Fired'}
# {u'_id': u'Noodles in the Pot'}
# {u'_id': u'Las Fuentes'}
# {u'_id': u'Select Cut Steak House', u'cuisine': u'steak'}
# {u'_id': u'Chicago Diner', u'cuisine': u'diner'}
# {u'_id': u'Golden House Restaurant', u'cuisine': u'diner'}
# {u'_id': u'Thai Pastry Restaurant', u'cuisine': u'thai'}
# {u'_id': u'Crepes on the Beach'}
# {u'_id': u'Starbucks', u'cuisine': u'coffee_shop'}
# {u'_id': u'Chicago Rib House', u'cuisine': u'meat'}
# {u'_id': u'Pizza Nova Express', u'cuisine': u'pizza'}
# {u'_id': u"Connie's Pizza", u'cuisine': u'pizza'}
# {u'_id': u'White Palace Grill', u'cuisine': u'Diner'}
# {u'_id': u"Lou Malnati's Pizzeria", u'cuisine': u'pizza'}
# {u'_id': u"Carson's", u'cuisine': u'ribs'}
# {u'_id': u'Fogo De Chao'}
# {u'_id': u"Hooter's Restaurant"}
# {u'_id': u"Lou Malnati's", u'cuisine': u'pizza'}
# {u'_id': u'China Doll', u'cuisine': u'chinese'}
# {u'_id': u'Salpicon', u'cuisine': u'mexican'}
# {u'_id': u'Original Pancake House'}
# {u'_id': u'Les Nomades', u'contact': u'+1.312.649.9010', u'cuisine': u'french'}
# {u'_id': u"Sammy's Red Hots",
#  u'contact': u'312-266-7290',
#  u'cuisine': u'pizza'}
# {u'_id': u'Baba Place', u'cuisine': u'indian; pakistani'}
# {u'_id': u'Eataly'}
# {u'_id': u'Gene & Georgetti'}
# {u'_id': u'Bella Luna Cafe'}
# {u'_id': u"Pizano's Pizza & Pasta", u'cuisine': u'pizza;pasta'}
# {u'_id': u"Gino's East", u'cuisine': u'pizza'}
# {u'_id': u'Pizzeria Uno'}
# {u'_id': u"Portillo's"}
# {u'_id': u"Elly's Pancake House",
#  u'contact': u'(312) 643-2300',
#  u'cuisine': u'breakfast'}
# {u'_id': u"Orso's", u'cuisine': u'italian'}
# {u'_id': u"Kilwin's", u'cuisine': u'ice_cream'}
# {u'_id': u'Old Jerusalem'}
# {u'_id': u"Lan's China Bistro", u'cuisine': u'chinese'}
# {u'_id': u"Woodie's"}
# {u'_id': u'My Fit Foods'}
# {u'_id': u"Giordano's Pizza", u'cuisine': u'pizza'}
# {u'_id': u"Pepe's Mexican Restaurant"}
# {u'_id': u'Calumet Fisheries', u'cuisine': u'fish'}
# {u'_id': u'El Progreso'}
# {u'_id': u"Chili's", u'cuisine': u'american'}
# {u'_id': u'Hofbr\xe4uhaus Chicago', u'cuisine': u'german'}
# {u'_id': u"Herm's Palace", u'cuisine': u'sausage'}
# {u'_id': u'Macaroni Grill', u'cuisine': u'italian'}
# {u'_id': u'Home Run Inn Pizza', u'cuisine': u'pizza'}
# {u'_id': u"Chili's"}
# {u'_id': u'Texas Corral'}
# {u'_id': u'The Lucky Monk', u'cuisine': u'burger'}
# {u'_id': u"Emilio's Tapas Restraurant"}
# {u'_id': u'Marquee Restaurant'}
# {u'_id': u'Medici'}
# {u'_id': u"Pitchin' Kitchen"}
# {u'_id': u'Olive Garden', u'cuisine': u'italian'}
# {u'_id': u'Country House'}
# {u'_id': u'Browns Chicken', u'cuisine': u'Chicken_Restaurant'}
# {u'_id': u'Mattesons', u'cuisine': u'steak_house'}
# {u'_id': u'Bakers Square', u'cuisine': u'Bakery'}
# {u'_id': u"Denny's"}
# {u'_id': u"Dell Rhea's Chicken Basket"}
# {u'_id': u"McDonald's"}
# {u'_id': u'Mr. Submarine'}
# {u'_id': u'Boston Market'}
# {u'_id': u"Portillo's", u'cuisine': u'burger'}
# {u'_id': u'Walker Bros. Pancake House',
#  u'contact': u'847-251-6000',
#  u'cuisine': u'breakfast'}
# {u'_id': u'Bistrot Margot'}
# {u'_id': u'The Assembly', u'cuisine': u'burger'}
# {u'_id': u'ihop'}
# {u'_id': u'Red Lobster'}
# {u'_id': u"Giordano's", u'cuisine': u'pizza'}
# {u'_id': u"Kappy's Restaurant", u'cuisine': u'pancake'}
# {u'_id': u'Pizza Hut', u'cuisine': u'pizza'}
# {u'_id': u'MC Boppers'}
# {u'_id': u"Denny's", u'cuisine': u'american'}
# {u'_id': u"Portillo's Hot Dogs"}
# {u'_id': u'Benihana', u'cuisine': u'japanese'}
# {u'_id': u'Jerseys', u'cuisine': u'burger'}
# {u'_id': u"Fuddrucker's", u'cuisine': u'burger'}
# {u'_id': u'Hooters'}
# {u'_id': u'Bahama Breeze'}
# {u'_id': u"Portillo's", u'cuisine': u'hotdog'}
# {u'_id': u'Tango'}
# {u'_id': u"Denny's"}
# {u'_id': u'Outback', u'cuisine': u'steak'}
# {u'_id': u'Club Lago', u'cuisine': u'italian'}
# {u'_id': u'Dairy Queen', u'cuisine': u'ice_cream'}
# {u'_id': u'McDonalds'}
# {u'_id': u"Mr. Beefy's"}
# {u'_id': u'Red Lobster', u'cuisine': u'seafood'}
# {u'_id': u'Greek Village', u'cuisine': u'greek'}
# {u'_id': u'Boston Market'}
# {u'_id': u'Wildfire'}
# {u'_id': u'California Pizza Kitchen', u'cuisine': u'pizza'}
# {u'_id': u"Culver's", u'contact': u'(630) 444-1700', u'cuisine': u'american'}
# {u'_id': u"McDonald's"}
# {u'_id': u'Cracker Barrel',
#  u'contact': u'630-778-6699',
#  u'cuisine': u'regional'}
# {u'_id': u'RAM'}
# {u'_id': u'Beef Shack'}
# {u'_id': u"Nino's", u'cuisine': u'pizza'}
# {u'_id': u'Weber Grill Restaurant'}
# {u'_id': u'White Chocolate'}
# {u'_id': u'Omega'}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Dennys'}
# {u'_id': u'Seasons 52'}
# {u'_id': u'The Capital Grille'}
# {u'_id': u'Chiu Quon', u'cuisine': u'vietnamese'}
# {u'_id': u'El Pueblito Mexican Grill #2', u'cuisine': u'mexican'}
# {u'_id': u"Dante's House of Pizza",
#  u'contact': u'(219) 924-2200',
#  u'cuisine': u'pizza'}
# {u'_id': u'IHOP'}
# {u'_id': u'Siri Thai', u'cuisine': u'thai'}
# {u'_id': u'Red Robin', u'cuisine': u'burger'}
# {u'_id': u'California Pizza Kitchen', u'cuisine': u'pizza'}
# {u'_id': u'Stoney River', u'cuisine': u'steak_house'}
# {u'_id': u"Donelli's Pizza", u'contact': u'+12193746859', u'cuisine': u'pizza'}
# {u'_id': u"Rosie's"}
# {u'_id': u"Jim and Pete's",
#  u'contact': u'(708) 453-5204',
#  u'cuisine': u'italian'}
# {u'_id': u"Russell's Barbecue",
#  u'contact': u'(708) 453-7065',
#  u'cuisine': u'barbecue'}
# {u'_id': u'Einstein Bros. Bagels', u'cuisine': u'bagel,_sandwich'}
# {u'_id': u'Firecakes'}
# {u'_id': u'Bub City'}
# {u'_id': u"Arby's", u'cuisine': u'american'}
# {u'_id': u'Red Lobster', u'cuisine': u'seafood'}
# {u'_id': u"Nick's Pizza and Pub",
#  u'contact': u'(815) 356-5550',
#  u'cuisine': u'pizza'}
# {u'_id': u'Buona Beef'}
# {u'_id': u'Rosewood'}
# {u'_id': u'Ram Restaurant & Brewery'}
# {u'_id': u'Two Brothers Round House', u'contact': u'630.264.2739'}
# {u'_id': u'Olive Garden', u'cuisine': u'italian'}
# {u'_id': u"Brown's Chicken"}
# {u'_id': u'Las Palmas', u'cuisine': u'mexican'}
# {u'_id': u"Portillo's"}
# {u'_id': u'Outback Steakhouse'}
# {u'_id': u'El Zarape', u'cuisine': u'mexican'}
# {u'_id': u"Gino's East", u'cuisine': u'pizza'}
# {u'_id': u'Dairy Queen', u'cuisine': u'ice_cream'}
# {u'_id': u'Jack Straws'}
# {u'_id': u'The Dawson'}
# {u'_id': u'Tusk', u'contact': u'1 630 406 6995', u'cuisine': u'thai'}
# {u'_id': u"Grandma Sally's"}
# {u'_id': u'Pampas Argentine Steak House'}
# {u'_id': u'Panera', u'cuisine': u'american'}
# {u'_id': u"Gemato's Wood Pit BBQ"}
# {u'_id': u'Mongo McMichaels', u'contact': u'+1 630 7391661'}
# {u'_id': u'White Fence Farm', u'contact': u'630 7391720'}
# {u'_id': u'Lemon Tree Family Restaurant', u'cuisine': u'american'}
# {u'_id': u"Venuti's Restaurant", u'cuisine': u'italian'}
# {u'_id': u"Nick's Barbecue",
#  u'contact': u'+1 815 3720578',
#  u'cuisine': u'barbecue'}
# {u'_id': u"Johnnie's Beef", u'cuisine': u'burger'}
# {u'_id': u"Cooper's Hawk", u'contact': u'847-836-9463'}
# {u'_id': u"McDonald's", u'cuisine': u'american'}
# {u'_id': u'Home Run Inn Pizza', u'cuisine': u'pizza'}
# {u'_id': u'International House of Pancakes', u'cuisine': u'american'}
# {u'_id': u"Famous Dave's", u'cuisine': u'barbecue'}
# {u'_id': u'LongHorn Steakhouse', u'cuisine': u'steak_house'}
# {u'_id': u'Cracker Barrel'}
# {u'_id': u'Claim Jumper', u'cuisine': u'regional'}
# {u'_id': u"Chili's"}
# {u'_id': u'Panera Bread'}
# {u'_id': u'Quaker Steak and Lube'}
# {u'_id': u"Giordano's", u'cuisine': u'italian'}
# {u'_id': u"Penny's Noodle Shop", u'cuisine': u'thai'}
# {u'_id': u"Augustino's Rock and Roll Diner"}
# {u'_id': u'L.Woods', u'cuisine': u'american'}
# {u'_id': u'Tsukasa of Tokyo', u'cuisine': u'japanese'}
# {u'_id': u"JK's Restaurant"}
# {u'_id': u'Sushi Station', u'cuisine': u'sushi'}
# {u'_id': u'Panera Bread'}
# {u'_id': u"Rookey's Sports Bar", u'cuisine': u'american'}
# {u'_id': u"Jimmy John's", u'cuisine': u'sandwich'}
# {u'_id': u'Mr. Wok', u'cuisine': u'chinese'}
# {u'_id': u"Big Sammy's Hotdogs", u'cuisine': u'hot_dogs'}
# {u'_id': u'Burnt Toast', u'cuisine': u'american'}
# {u'_id': u'Village Pizza and Pub', u'cuisine': u'pizza'}
# {u'_id': u'South Side Pizzeria',
#  u'contact': u'+12193746400',
#  u'cuisine': u'pizza'}
# {u'_id': u'China House', u'contact': u'+12193749888', u'cuisine': u'chinese'}
# {u'_id': u"Denny's"}
# {u'_id': u'Bangkok Wok', u'cuisine': u'thai'}
# {u'_id': u"Leona's"}
# {u'_id': u'IHOP'}
# {u'_id': u'Oberweiss; That Burger Joint'}
# {u'_id': u'Pappadeaux seafood kitchen'}
# {u'_id': u'Big Hurt Brewhouse'}
# {u'_id': u'El Habanero', u'contact': u'(773) 227-9225', u'cuisine': u'mexican'}
# {u'_id': u"Henry's Hotdogs", u'cuisine': u'Hotdogs'}
# {u'_id': u'Paisans Pizzeria & Bar', u'cuisine': u'pizza'}
# {u'_id': u"Mr A's Italian Beef",
#  u'contact': u'(815) 459-9150',
#  u'cuisine': u'italian_beef'}
# {u'_id': u'Smash Burger'}
# {u'_id': u'Blueberry Hill', u'contact': u'(708) 352-4900'}
# {u'_id': u'Woow Sushi', u'cuisine': u'chinese'}
# {u'_id': u'Kama Indian Bistro', u'cuisine': u'indian'}
# {u'_id': u'Back Alley Burger',
#  u'contact': u'708-482-7909',
#  u'cuisine': u'burger'}
# {u'_id': u"Aurelio's Pizza",
#  u'contact': u'(708) 579-0900',
#  u'cuisine': u'pizza'}
# {u'_id': u"Marconi's Ristorante", u'cuisine': u'italian'}
# {u'_id': u'Thipi Thai', u'cuisine': u'thai'}
# {u'_id': u'Owen & Engine', u'cuisine': u'british'}
# {u'_id': u'Longhorn Steakhouse',
#  u'contact': u'+1 630 7830684',
#  u'cuisine': u'steak_house'}
# {u'_id': u"Famous Dave's",
#  u'contact': u'+1 630 7831502',
#  u'cuisine': u'barbecue'}
# {u'_id': u'Buffalo Wild Wings', u'contact': u'+1 630 7392999'}
# {u'_id': u"Upton's Breakroom", u'cuisine': u'vegetarian'}
# {u'_id': u'Carluci Restaurant & Bar', u'cuisine': u'italian'}
# {u'_id': u'Taquiera Los Comales', u'cuisine': u'mexican'}
# {u'_id': u"Cheddar's"}
# {u'_id': u'Cracker Barrel',
#  u'contact': u'630-759-6171',
#  u'cuisine': u'regional'}
# {u'_id': u'Tilted Kilt'}
# {u'_id': u"Chili's"}
# {u'_id': u"P.F. Chang's"}
# {u'_id': u'Weber Grill'}
# {u'_id': u"Uncle Julio's"}
# {u'_id': u"Tiffany's Restaurant"}
# {u'_id': u"Chili's", u'cuisine': u'mexican'}
# {u'_id': u'Olive Garden', u'cuisine': u'italian'}
# {u'_id': u'Dock Rotz Tavern'}
# {u'_id': u"EJ's Place", u'cuisine': u'steak_house'}
# {u'_id': u'Joyce Lee China Buffet', u'cuisine': u'chinese'}
# {u'_id': u'Sakura Sushi', u'cuisine': u'japanese'}
# {u'_id': u'Los Burritos', u'cuisine': u'mexican'}
# {u'_id': u"Dominick's Pizza & Pasta", u'cuisine': u'italian'}
# {u'_id': u'Zhivago', u'cuisine': u'Russian'}
# {u'_id': u"Smokey's Woodpit BBQ", u'cuisine': u'barbecue'}
# {u'_id': u"Hardee's", u'cuisine': u'american'}
# {u'_id': u'The Docks'}
# {u'_id': u'McDonalds', u'cuisine': u'burger'}
# {u'_id': u'Subway', u'cuisine': u'sandwich'}
# {u'_id': u"Alexander's "}
# {u'_id': u"Steve's Gyro", u'cuisine': u'american'}
# {u'_id': u'Gale Street Inn', u'cuisine': u'american'}
# {u'_id': u'Taqueria La Estrella', u'cuisine': u'mexican'}
# {u'_id': u"McDonald's", u'cuisine': u'burger'}
# {u'_id': u'Burger King', u'cuisine': u'burger'}
# {u'_id': u'Old Warsaw', u'cuisine': u'polish'}
# {u'_id': u'The Great Escape', u'contact': u'+1 847 671 7171'}
# {u'_id': u'American Wild Burger', u'cuisine': u'burger'}
# {u'_id': u'Boston Fish', u'cuisine': u'seafood'}
# {u'_id': u'Silver Stallion', u'cuisine': u'american'}
# {u'_id': u'Buffalo Wild Wings', u'cuisine': u'wings'}
# {u'_id': u'Embers Tap House',
#  u'contact': u'815-552-3031',
#  u'cuisine': u'burger'}
# {u'_id': u"Mamma Onesta's Italian Restaurant",
#  u'contact': u'(815) 588-0900',
#  u'cuisine': u'italian'}
# {u'_id': u'Rising Sun', u'cuisine': u'cantonese'}
# {u'_id': u"Fleckenstein's Bakery", u'cuisine': u'bakery'}
# {u'_id': u'Cracker Barrel',
#  u'contact': u'219-947-2617',
#  u'cuisine': u'regional'}
# {u'_id': u'Cracker Barrel',
#  u'contact': u'219-844-1259',
#  u'cuisine': u'regional'}
# {u'_id': u'Ridgeview Grill', u'cuisine': u'american'}
# {u'_id': u'Snuggery'}
# {u'_id': u"Applebee's"}
# {u'_id': u"Steak 'n Shake", u'cuisine': u'burger'}
# {u'_id': u'Taco Bell', u'contact': u'(847)517-8320', u'cuisine': u'mexican'}
# {u'_id': u"Harry Carry's Seventh Inning Stretch"}
# {u'_id': u'Illinois Bar & Grill'}
# {u'_id': u'King Wah Express'}
# {u'_id': u"Lalo's Mexican Restaurant"}
# {u'_id': u'Luigi Stefani Pizzeria'}
# {u'_id': u'Potbelly Sandwich Works'}
# {u'_id': u"Reilly's Daughter"}
# {u'_id': u'Tilted Kilt'}
# {u'_id': u"Chili's"}

# %%
# Sort cities by count, descending

def cities():
    result  = db.osm_final.aggregate([{"$match":{"address.city":{"$exists":1}}}, 
                   {"$group":{"_id":"$address.city", "count":{"$sum":1}}}, 
                   {"$sort":{"count":1}}])

    for a in result:
            pprint.pprint(a)

cities()
# Out:
# {u'_id': u'Griffith', u'count': 1}
# {u'_id': u'http://www.woodlawngrant-apts.com/', u'count': 1}
# {u'_id': u'Lynwood', u'count': 1}
# {u'_id': u'Markham', u'count': 1}
# {u'_id': u'Dyer', u'count': 1}
# {u'_id': u'Porter', u'count': 1}
# {u'_id': u'Addon', u'count': 1}
# {u'_id': u'Prospect Heights', u'count': 1}
# {u'_id': u'Saint John', u'count': 1}
# {u'_id': u'elmhurst', u'count': 1}
# {u'_id': u'Stone Park', u'count': 1}
# {u'_id': u'Dixmoor', u'count': 1}
# {u'_id': u'Itasca', u'count': 1}
# {u'_id': u'Hebron', u'count': 1}
# {u'_id': u'Orland Hills', u'count': 1}
# {u'_id': u'Glenwood', u'count': 1}
# {u'_id': u'Chciago', u'count': 1}
# {u'_id': u'60706', u'count': 1}
# {u'_id': u'CHicago', u'count': 1}
# {u'_id': u'mount prospect', u'count': 1}
# {u'_id': u'Green Oaks', u'count': 1}
# {u'_id': u'Flossmoor', u'count': 1}
# {u'_id': u'Posen', u'count': 1}
# {u'_id': u'Park Forest', u'count': 1}
# {u'_id': u'Montgomery', u'count': 1}
# {u'_id': u'Hawthorn Woods', u'count': 1}
# {u'_id': u'Olympia Fields', u'count': 1}
# {u'_id': u'Beecher', u'count': 1}
# {u'_id': u'BUFFALO GROVE', u'count': 1}
# {u'_id': u'forest Park', u'count': 1}
# {u'_id': u'La Grange Road', u'count': 1}
# {u'_id': u'Oswego', u'count': 1}
# {u'_id': u'Hometown', u'count': 1}
# {u'_id': u'BOLINGBROOK', u'count': 1}
# {u'_id': u'Joliet, Illinois', u'count': 1}
# {u'_id': u'Crest Hill', u'count': 1}
# {u'_id': u'st charles', u'count': 1}
# {u'_id': u'Lake Barrington', u'count': 1}
# {u'_id': u'Justice', u'count': 1}
# {u'_id': u'plainfield', u'count': 1}
# {u'_id': u'libertyville', u'count': 1}
# {u'_id': u'Monee', u'count': 1}
# {u'_id': u'Illinois', u'count': 1}
# {u'_id': u'Crest Hill, IL', u'count': 1}
# {u'_id': u'Barrinton', u'count': 1}
# {u'_id': u'riverside', u'count': 1}
# {u'_id': u'Kildeer', u'count': 1}
# {u'_id': u'Chicago, IL', u'count': 1}
# {u'_id': u'Carpentesville', u'count': 1}
# {u'_id': u'Argonne', u'count': 1}
# {u'_id': u'Hazel Crest', u'count': 1}
# {u'_id': u'Des Plaine', u'count': 1}
# {u'_id': u'crystal lake', u'count': 1}
# {u'_id': u'Fox River Grove', u'count': 1}
# {u'_id': u'Dolton', u'count': 1}
# {u'_id': u'Calumet Park', u'count': 2}
# {u'_id': u'Riverwoods', u'count': 2}
# {u'_id': u'Hodgkins', u'count': 2}
# {u'_id': u'Channahon', u'count': 2}
# {u'_id': u'South Chicago Heights', u'count': 2}
# {u'_id': u'Sugar Grove', u'count': 2}
# {u'_id': u'Clarendon Hills', u'count': 2}
# {u'_id': u'Bridgeview', u'count': 2}
# {u'_id': u'Elburn', u'count': 2}
# {u'_id': u'Riverside', u'count': 2}
# {u'_id': u'Melrose Park, IL', u'count': 2}
# {u'_id': u'Shorewood', u'count': 2}
# {u'_id': u'60623', u'count': 2}
# {u'_id': u'Prairie Grove', u'count': 2}
# {u'_id': u'Willow Springs', u'count': 2}
# {u'_id': u'North Barrington', u'count': 2}
# {u'_id': u'Golf', u'count': 2}
# {u'_id': u'Brookfield', u'count': 2}
# {u'_id': u'Wauconda', u'count': 2}
# {u'_id': u'St Charles', u'count': 2}
# {u'_id': u'Homewood', u'count': 2}
# {u'_id': u'ROMEOVILLE', u'count': 2}
# {u'_id': u'Melrose Park', u'count': 2}
# {u'_id': u'Bolingbrook', u'count': 62}
# {u'_id': u'Forest Park', u'count': 64}
# {u'_id': u'Winfield', u'count': 65}
# {u'_id': u'Carol Stream', u'count': 67}
# {u'_id': u'Huntley', u'count': 82}
# {u'_id': u'Wilmette', u'count': 92}
# {u'_id': u'Schaumburg', u'count': 168}
# {u'_id': u'Streamwood', u'count': 191}
# {u'_id': u'Valparaiso', u'count': 230}
# {u'_id': u'Skokie', u'count': 248}
# {u'_id': u'Glen Ellyn', u'count': 262}
# {u'_id': u'Wheaton', u'count': 296}
# {u'_id': u'Hoffman Estates', u'count': 306}
# {u'_id': u'Downers Grove', u'count': 326}
# {u'_id': u'Gilberts', u'count': 356}
# {u'_id': u'Hinsdale', u'count': 411}
# {u'_id': u'Lombard', u'count': 596}
# {u'_id': u'Buffalo Grove', u'count': 837}
# {u'_id': u'River Forest', u'count': 1735}
# {u'_id': u'Chicago', u'count': 2271}
# {u'_id': u'Evanston', u'count': 17101}

# %%
def find_2():
    result = db.osm_final.find({'city':'Evanston'})
    for a in result:
        pprint.pprint(a)
        
find_2()

# %%
# Number of documents
db.osm_final.find().count()
# Out:
# 9586971

# %%
# Number of nodes
db.osm_final.find({"type":"node"}).count()
# Out:
# 8399395

# %%
# Number of ways
db.osm_final.find({"type":"way"}).count()
# Out:
# 1187370

# %%
# Number of unique users

def unique_Users():
    result = db.osm_final.aggregate([{'$group':{'_id':'$created.user','count':{'$sum':1}}}, 
                        {'$group':{'_id':'$created.user', 'count':{"$sum":1}}}
                         ])
    for a in result:
        pprint.pprint(a)

unique_Users()
# Out:
# {u'_id': None, u'count': 2274}

# %%
# Top 5 contributing user

def con_user():
    result = db.osm_final.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}, 
                                     {"$sort":{"count":-1}}, 
                                     {"$limit":5}]
                                   )     
    for a in result:
        pprint.pprint(a)
        
        
con_user()
# Out:
# {u'_id': u'chicago-buildings', u'count': 5635534}
# {u'_id': u'Umbugbene', u'count': 1101042}
# {u'_id': u'alexrudd (NHD)', u'count': 232740}
# {u'_id': u'woodpeck_fixbot', u'count': 225702}
# {u'_id': u'patester24', u'count': 109091}

# %%
# Number of users appearing only once (having 1 post)
def num_user():
    result = db.osm_final.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}, 
                        {"$group":{"_id":"$count", "num_users":{"$sum":1}}}, 
                        {"$sort":{"_id":1}}, {"$limit":1}])
    for a in result:
        pprint.pprint(a)

num_user()
# Out:
# {u'_id': 1, u'num_users': 503}

# %%
# Total Number of Amenities
# Covering an assortment of community facilities including toilets, 
# telephones, banks, pharmacies and schools.
def amenities():
    result = db.osm_final.aggregate([{"$match":{"amenity":{"$exists":True}}}, 
                        {"$group":{"_id":"$amenity", "count":{"$sum":1}}}, 
                        {'$group':{'_id':'$amenity', 'count':{'$sum':'$count'}}}
                         ])
    for a in result:
        pprint.pprint(a)

amenities()
# Out:
# {u'_id': None, u'count': 31821}

# %%
# Total Number of Unique Amenities
# Covering an assortment of community facilities including toilets, 
# telephones, banks, pharmacies and schools.
def amenities_unique():
    result = db.osm_final.aggregate([{'$group':{'_id':'$amenity','count':{'$sum':1}}}, 
                        {'$group':{'_id':'$amenity', 'count':{"$sum":1}}}
                         ])
    for a in result:
        pprint.pprint(a)

amenities_unique()
# Out:
# {u'_id': None, u'count': 145}

# %%
# Top 10 Amenities
def amenities_top():
    result = db.osm_final.aggregate([{'$match':{'amenity':{'$exists':True}}}, 
                        {'$group':{'_id':'$amenity', 'count':{"$sum":1}}},
                                     {'$sort':{'count':-1}},
                                     {'$limit':10}
                         ])
    for a in result:
        pprint.pprint(a)

amenities_top()
# Out:
# {u'_id': u'parking', u'count': 12577}
# {u'_id': u'place_of_worship', u'count': 4305}
# {u'_id': u'school', u'count': 3423}
# {u'_id': u'restaurant', u'count': 1967}
# {u'_id': u'fast_food', u'count': 1369}
# {u'_id': u'fuel', u'count': 805}
# {u'_id': u'bank', u'count': 595}
# {u'_id': u'cafe', u'count': 455}
# {u'_id': u'grave_yard', u'count': 450}
# {u'_id': u'pharmacy', u'count': 370}

# %%
# One Cuisine
def Cuisine_top():
    result = db.osm_final.aggregate([{'$match':{'cuisine':{'$exists':True}}}, 
                        {'$group':{'_id':'$cuisine', 'count':{"$sum":1},'name':{'$push':'$name'}}},
                                     {'$sort':{'count':-1}},
                                     {'$limit':1}
                         ])
    for a in result:
        pprint.pprint(a)

Cuisine_top()
# Out:
# {u'_id': u'burger',
#  u'count': 494,
#  u'name': [u"McDonald's",
#            u'Char House Grill',
#            u"Clarke's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Branko's Submarines",
#            u"Wendy's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u"McDonald's",
#            u'Dear Franks',
#            u'Burger King',
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Budacki's",
#            u'Bad Apple',
#            u"McDonald's",
#            u"Wee-Dee's",
#            u"McDonald's",
#            u"Wendy's",
#            u'Burger King',
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u'Steak & Shake',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'Five Guys',
#            u"Wendy's",
#            u'White Castle',
#            u'White Castle',
#            u"McDonald's",
#            u'Burger King',
#            u'Burger King',
#            u'Meatheads',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Tracks Bar & Grill',
#            u'Rockit Burger Bar',
#            u"McDonald's",
#            u'Burger King',
#            u'Evanston Grill',
#            u"McDonald's",
#            u'Five Guys Burgers',
#            u'Sonic',
#            u"Lindy's Chili",
#            u"McDonald's",
#            u"Edzo's Burger Shop",
#            u'Patellis',
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'McDonalds',
#            u'Burger Bar Chicago',
#            u'Little Island Hot Dogs',
#            u'Burger King',
#            u"Wendy's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'Jack & Pats',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Five Guys',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Fatty's Burgers and More",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'Five Guys',
#            u'Epic Burger',
#            u"Culver's",
#            u'Burger King',
#            u"McDonald's",
#            u'Meatheads',
#            u'Doggie Diner',
#            u'Red Robin',
#            u'Panera Bread',
#            u'Ace Drive-In',
#            u"Johnny's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Daddy O\u2019s Diner of Itasca',
#            u"McDonald's",
#            u'M Burger',
#            u'Burger King',
#            u'Burger King',
#            u'Billy Goat Tavern',
#            u'Burger Joint',
#            u"McDonald's",
#            u"McDonald's",
#            u'McDonalds',
#            u"McDonald's",
#            u'BurgerFi',
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'Leader Bar Drafthouse',
#            u"McDonald's",
#            u'Smashburger',
#            u'Five Guys Burgers and Fries',
#            u"McDonald's",
#            u"Hardee's",
#            u"Frank's Red Hots",
#            u'Dogfather',
#            u"McDonald's",
#            u'The Harding Tavern',
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u"Chef's Burger Bistro",
#            u'Potbelly Sandwich Shop',
#            u'Sonic',
#            u'Parts & Labor',
#            u'Epic Burger',
#            u"Kuma's Too",
#            u"Kuma's Corner",
#            u'Burger King',
#            u'Burger King',
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger King',
#            u"Phil's Kastle",
#            u'Burger King',
#            u"Irving's",
#            u'Burgerking',
#            u'Shake Shack',
#            u'Burger King',
#            u'Patio Beef',
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger Bar',
#            u"McDonald's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Jak's Tap",
#            u'Express Grill',
#            u'Burger King',
#            u"McDonald's",
#            u'BeefBelly',
#            u'White Castle',
#            u'Burger King',
#            u"Mcdonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'Lockdown Bar & Grill',
#            u'Crusade Burger Bar',
#            u"Rowdy's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"Culver's",
#            u"McDonald's",
#            u"That's a Burger",
#            u"McDonald's",
#            u"McDonald's",
#            u'Steak n Shake',
#            u"Culver's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u"Culver's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger King',
#            u"Culver's",
#            u'White Castle',
#            u"McDonald's",
#            u"McDonald's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Culver's",
#            u"Wendy's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Steak N Shake',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'Five Guys',
#            u'Burger King',
#            u"McDonald's",
#            u'Steak and Shake',
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'U.B. Dogs',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'Burger King',
#            u"Rock N Roll McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u'Franksville',
#            u"Wendy's",
#            u'White Castle',
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Steak N SHake',
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u"Culver's",
#            u"McDonald's",
#            u'Rock Bottom',
#            u"McDonald's",
#            u"Wendy's",
#            u'Dennys',
#            u"Tom & Eddie's",
#            u'Sonic',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Sam's Red Hots",
#            u'Burger King',
#            u'Frank Meats Patty',
#            u"Wendy's",
#            u'The Northman',
#            u"McDonald's",
#            u"McDonald's",
#            u"Janson's Drive-In",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'Burger King',
#            u"McDonald's",
#            u"Wendy's",
#            u'Umami Burger',
#            u"Chopper's",
#            u'Small Cheval',
#            u"Wendy's",
#            u"Byron's Hotdogs",
#            u"Wendy's",
#            u"McDonald's",
#            u'White Castle',
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'The Butcher & the Burger',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u'https://www.checkers.com/',
#            u"McDonald's",
#            u"McDonald's",
#            u'Checkers',
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u'White Castle',
#            u'Burger King',
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u"McDonald's",
#            u"Checker's Drive-In",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u'White Castle',
#            u"Carl's Red Hots",
#            u"McDonald's",
#            u'Burger King',
#            u"Wendy's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"Bill's Drive-in",
#            u'The Lucky Monk',
#            u"Portillo's",
#            u"Culver's",
#            u'The Assembly',
#            u"McDonald's",
#            u"McDonald's",
#            u'Jerseys',
#            u'Burger King',
#            u"Fuddrucker's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"Mustard's Last Stand",
#            u"McDonald's",
#            u'Red Robin',
#            u"McDonald's",
#            u'White Castle',
#            u"McDonald's",
#            u"Wendy's",
#            u'Burger King',
#            u"McDonald's",
#            u'Burger King',
#            u"Portillo's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonnald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"McDonald's",
#            u"McDonald's",
#            u"Wendy's",
#            u"Johnnie's Beef",
#            u'Burger King',
#            u'Burger King',
#            u'Burger King',
#            u"McDonald's",
#            u'Five Guys',
#            u"Tore & Luke's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Back Alley Burger',
#            u'Burger King',
#            u'Burger King',
#            u'Burger King',
#            u"Culver's",
#            u"McDonald's",
#            u"Wendy's",
#            u"Wendy's",
#            u'White Castle',
#            u'Sonic',
#            u"Culver's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u'McDonalds',
#            u"Wendy's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u'Burger King',
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u"McDonald's",
#            u'American Wild Burger',
#            u'Burger King',
#            u'M Burger',
#            u"Wendy's",
#            u"McDonald's",
#            u'Embers Tap House',
#            u"McDonald's",
#            u"Wendy's",
#            u"Wendy's",
#            u"McDonald's",
#            u"Steak 'n Shake",
#            u'Burger King',
#            u'White Castle',
#            u"Jim's Original",
#            u'Express Grill']}
